# %%
# %load_ext autoreload
# %autoreload 2

# %%
# pip install -r requirements.txt
# !pip install -e ./

import sys
# !{sys.executable} -m pip install -e ./
# Out:
# Obtaining file:///home/ivelin/canswim
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: darts in /home/ivelin/anaconda3/lib/python3.11/site-packages (from canswim==0.0.1) (0.27.1)
# Requirement already satisfied: yfinance in /home/ivelin/anaconda3/lib/python3.11/site-packages (from canswim==0.0.1) (0.2.33)
# Requirement already satisfied: fmpsdk in /home/ivelin/anaconda3/lib/python3.11/site-packages (from canswim==0.0.1) (20230623.0)
# Requirement already satisfied: optuna==3.4.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from canswim==0.0.1) (3.4.0)
# Requirement already satisfied: huggingface_hub in /home/ivelin/anaconda3/lib/python3.11/site-packages (from canswim==0.0.1) (0.15.1)
# Requirement already satisfied: alembic>=1.5.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from optuna==3.4.0->canswim==0.0.1) (1.13.1)
# Requirement already satisfied: colorlog in /home/ivelin/anaconda3/lib/python3.11/site-packages (from optuna==3.4.0->canswim==0.0.1) (6.8.2)
# Requirement already satisfied: numpy in /home/ivelin/anaconda3/lib/python3.11/site-packages (from optuna==3.4.0->canswim==0.0.1) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from optuna==3.4.0->canswim==0.0.1) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from optuna==3.4.0->canswim==0.0.1) (1.4.39)
# Requirement already satisfied: tqdm in /home/ivelin/anaconda3/lib/python3.11/site-packages (from optuna==3.4.0->canswim==0.0.1) (4.65.0)
# Requirement already satisfied: PyYAML in /home/ivelin/anaconda3/lib/python3.11/site-packages (from optuna==3.4.0->canswim==0.0.1) (6.0)
# Requirement already satisfied: holidays>=0.11.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (0.39)
# Requirement already satisfied: joblib>=0.16.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (1.2.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (3.7.2)
# Requirement already satisfied: nfoursid>=1.0.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (1.0.1)
# Requirement already satisfied: pmdarima>=1.8.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (2.0.4)
# Requirement already satisfied: pyod>=0.9.5 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (1.1.2)
# Requirement already satisfied: requests>=2.22.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (1.3.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (1.11.1)
# Requirement already satisfied: shap>=0.40.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (0.44.0)
# Requirement already satisfied: statsforecast>=1.4 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (1.7.0)
# Requirement already satisfied: statsmodels>=0.14.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (0.14.0)
# Requirement already satisfied: tbats>=1.1.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (1.1.3)
# Requirement already satisfied: typing-extensions in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (4.7.1)
# Requirement already satisfied: xarray>=0.17.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (2023.6.0)
# Requirement already satisfied: xgboost>=1.6.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (2.0.3)
# Requirement already satisfied: pytorch-lightning>=1.5.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (2.1.3)
# Requirement already satisfied: tensorboardX>=2.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (2.6.2.2)
# Requirement already satisfied: torch>=1.8.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (2.1.2)
# Requirement already satisfied: pandas>=1.0.5 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from darts->canswim==0.0.1) (2.0.3)
# Requirement already satisfied: python-dotenv in /home/ivelin/anaconda3/lib/python3.11/site-packages (from fmpsdk->canswim==0.0.1) (0.21.0)
# Requirement already satisfied: filelock in /home/ivelin/anaconda3/lib/python3.11/site-packages (from huggingface_hub->canswim==0.0.1) (3.9.0)
# Requirement already satisfied: fsspec in /home/ivelin/anaconda3/lib/python3.11/site-packages (from huggingface_hub->canswim==0.0.1) (2023.4.0)
# Requirement already satisfied: multitasking>=0.0.7 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from yfinance->canswim==0.0.1) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from yfinance->canswim==0.0.1) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from yfinance->canswim==0.0.1) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from yfinance->canswim==0.0.1) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from yfinance->canswim==0.0.1) (2.3.10)
# Requirement already satisfied: peewee>=3.16.2 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from yfinance->canswim==0.0.1) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from yfinance->canswim==0.0.1) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from yfinance->canswim==0.0.1) (1.1)
# Requirement already satisfied: Mako in /home/ivelin/anaconda3/lib/python3.11/site-packages (from alembic>=1.5.0->optuna==3.4.0->canswim==0.0.1) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance->canswim==0.0.1) (2.4)
# Requirement already satisfied: python-dateutil in /home/ivelin/anaconda3/lib/python3.11/site-packages (from holidays>=0.11.1->darts->canswim==0.0.1) (2.8.2)
# Requirement already satisfied: six>=1.9 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance->canswim==0.0.1) (1.16.0)
# Requirement already satisfied: webencodings in /home/ivelin/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance->canswim==0.0.1) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->darts->canswim==0.0.1) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->darts->canswim==0.0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->darts->canswim==0.0.1) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->darts->canswim==0.0.1) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->darts->canswim==0.0.1) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->darts->canswim==0.0.1) (3.0.9)
# Requirement already satisfied: tzdata>=2022.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from pandas>=1.0.5->darts->canswim==0.0.1) (2023.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from pmdarima>=1.8.0->darts->canswim==0.0.1) (3.0.7)
# Requirement already satisfied: urllib3 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from pmdarima>=1.8.0->darts->canswim==0.0.1) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from pmdarima>=1.8.0->darts->canswim==0.0.1) (68.0.0)
# Requirement already satisfied: numba>=0.51 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from pyod>=0.9.5->darts->canswim==0.0.1) (0.57.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from pytorch-lightning>=1.5.0->darts->canswim==0.0.1) (1.2.1)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from pytorch-lightning>=1.5.0->darts->canswim==0.0.1) (0.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from requests>=2.22.0->darts->canswim==0.0.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from requests>=2.22.0->darts->canswim==0.0.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from requests>=2.22.0->darts->canswim==0.0.1) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.1->darts->canswim==0.0.1) (2.2.0)
# Requirement already satisfied: slicer==0.0.7 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from shap>=0.40.0->darts->canswim==0.0.1) (0.0.7)
# Requirement already satisfied: cloudpickle in /home/ivelin/anaconda3/lib/python3.11/site-packages (from shap>=0.40.0->darts->canswim==0.0.1) (2.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from sqlalchemy>=1.3.0->optuna==3.4.0->canswim==0.0.1) (2.0.1)
# Requirement already satisfied: fugue>=0.8.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from statsforecast>=1.4->darts->canswim==0.0.1) (0.8.7)
# Requirement already satisfied: utilsforecast>=0.0.23 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from statsforecast>=1.4->darts->canswim==0.0.1) (0.0.23)
# Requirement already satisfied: patsy>=0.5.2 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from statsmodels>=0.14.0->darts->canswim==0.0.1) (0.5.3)
# Requirement already satisfied: protobuf>=3.20 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from tensorboardX>=2.1->darts->canswim==0.0.1) (4.25.1)
# Requirement already satisfied: sympy in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (1.11.1)
# Requirement already satisfied: networkx in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (3.1)
# Requirement already satisfied: jinja2 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->darts->canswim==0.0.1) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->darts->canswim==0.0.1) (12.3.101)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from fsspec->huggingface_hub->canswim==0.0.1) (3.8.5)
# Requirement already satisfied: triad>=0.9.3 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts->canswim==0.0.1) (0.9.3)
# Requirement already satisfied: adagio>=0.2.4 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts->canswim==0.0.1) (0.2.4)
# Requirement already satisfied: qpd>=0.4.4 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts->canswim==0.0.1) (0.4.4)
# Requirement already satisfied: fugue-sql-antlr>=0.1.6 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts->canswim==0.0.1) (0.2.0)
# Requirement already satisfied: sqlglot in /home/ivelin/anaconda3/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts->canswim==0.0.1) (20.5.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from numba>=0.51->pyod>=0.9.5->darts->canswim==0.0.1) (0.40.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->darts->canswim==0.0.1) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.8.0->darts->canswim==0.0.1) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub->canswim==0.0.1) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub->canswim==0.0.1) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub->canswim==0.0.1) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub->canswim==0.0.1) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub->canswim==0.0.1) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub->canswim==0.0.1) (1.2.0)
# Requirement already satisfied: antlr4-python3-runtime<4.12 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from fugue-sql-antlr>=0.1.6->fugue>=0.8.1->statsforecast>=1.4->darts->canswim==0.0.1) (4.11.1)
# Requirement already satisfied: pyarrow>=6.0.1 in /home/ivelin/anaconda3/lib/python3.11/site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast>=1.4->darts->canswim==0.0.1) (11.0.0)
# Requirement already satisfied: fs in /home/ivelin/anaconda3/lib/python3.11/site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast>=1.4->darts->canswim==0.0.1) (2.4.16)
# Installing collected packages: canswim
#   Attempting uninstall: canswim
#     Found existing installation: canswim 0.0.1
#     Uninstalling canswim-0.0.1:
#       Successfully uninstalled canswim-0.0.1
#   Running setup.py develop for canswim
# Successfully installed canswim-0.0.1

# %% [markdown]
# ## Setup third party service provider connections

# %%
import yfinance as yf
import pandas as pd
from pathlib import Path
import numpy as np

# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True)

FMP_API_KEY=os.getenv("FMP_API_KEY")

print(f'FMP_API_KEY={FMP_API_KEY!= None}')
# Out:
# FMP_API_KEY=True

# %% [markdown]
# ## Load list of IBD Growth Stocks

# %%
all_stocks_file = 'all_stocks.csv'

# %%
all_stock_set = set()
stock_files = [
    'IBD50.csv',
    'IBD250.csv',
    'ibdlive_picks.csv',
    'russell2000_iwm_holdings.csv',
    'sp500_ivv_holdings.csv',
    'nasdaq100_cndx_holdings.csv',
    all_stocks_file
    ]
for f in stock_files:
    fp = f'data/data-3rd-party/{f}'
    if Path(fp).is_file():
        stocks = pd.read_csv(fp)
        print(f'loaded {len(stocks)} symbols from {fp}')
        stock_set = set(stocks['Symbol'])
        print(f'{len(stock_set)} symbols in stock set')
        all_stock_set |= stock_set
        print(f'total symbols loaded: {len(all_stock_set)}')
    else:
        print(f'{fp} not found.')
# Out:
# loaded 50 symbols from data/data-3rd-party/IBD50.csv
# 50 symbols in stock set
# total symbols loaded: 50
# loaded 300 symbols from data/data-3rd-party/IBD250.csv
# 300 symbols in stock set
# total symbols loaded: 309
# loaded 434 symbols from data/data-3rd-party/ibdlive_picks.csv
# 292 symbols in stock set
# total symbols loaded: 437
# loaded 1974 symbols from data/data-3rd-party/russell2000_iwm_holdings.csv
# 1971 symbols in stock set
# total symbols loaded: 2262
# loaded 509 symbols from data/data-3rd-party/sp500_ivv_holdings.csv
# 509 symbols in stock set
# total symbols loaded: 2649
# loaded 110 symbols from data/data-3rd-party/nasdaq100_cndx_holdings.csv
# 109 symbols in stock set
# total symbols loaded: 2661
# loaded 2650 symbols from data/data-3rd-party/all_stocks.csv
# 2650 symbols in stock set
# total symbols loaded: 2673

# %%
len(all_stock_set), all_stock_set
# Out:
# (2673,
#  {'ASB',
#   'CIM',
#   'SEER',
#   'JANX',
#   'DOW',
#   'GDYN',
#   'LCNB',
#   'ARTNA',
#   'MNTK',
#   'SITC',
#   'AWR',
#   'WERN',
#   'IAS',
#   'GEVO',
#   'PKBK',
#   'PAGS',
#   'BTBT',
#   'FSLR',
#   'EYEN',
#   'GTLB',
#   'GEFB',
#   'WRK',
#   'TDY',
#   'SONO',
#   'MLP',
#   'TARS',
#   'SPT',
#   'ATLC',
#   'CXM',
#   'CHRS',
#   'IPI',
#   'FLYW',
#   'SBGI',
#   'GSHD',
#   'CCSI',
#   'BITO',
#   'IOT',
#   'LNN',
#   'TILE',
#   'MTRN',
#   'CLMB',
#   'ECL',
#   'OTTR',
#   'DAL',
#   'OKE',
#   'AMT',
#   'CUBI',
#   'IMGN',
#   'DORM',
#   'MET',
#   'PRAA',
#   'MRK',
#   'COFS',
#   'VCEL',
#   'WSR',
#   'CVBF',
#   'HQI',
#   'DCPH',
#   'DGICA',
#   'COOK',
#   'SKIN',
#   'KALU',
#   'REG',
#   'ONL',
#   'CDZI',
#   'GDDY',
#   'BKU',
#   'AMN',
#   'BBUC',
#   'P5N994',
#   'AVAH',
#   'DZSI',
#   'UNTY',
#   'PEP',
#   'TDUP',
#   'FCEL',
#   'ZURA',
#   'JNJ',
#   'ACRE',
#   'LNTH',
#   'SRRK',
#   'MMYT',
#   'VTOL',
#   'DO',
#   'DLTH',
#   'NBN',
#   'HRT',
#   'NOG',
#   'SUPN',
#   'GLT',
#   'CPSS',
#   'MRTN',
#   'ARWR',
#   'MGNI',
#   'TGH',
#   'SAMG',
#   'PETS',
#   'TSE',
#   'KMX',
#   'BLK',
#   'ANET',
#   'POWW',
#   'ULTA',
#   'OSPN',
#   'DEA',
#   'REVG',
#   'BHLB',
#   'VSTO',
#   'NIC',
#   'DUK',
#   'MOH',
#   'UMBF',
#   'CSR',
#   'PH',
#   'WRBY',
#   'ELF',
#   'PSX',
#   'TREX',
#   'OPEN',
#   'HBAN',
#   'RGA',
#   'HQY',
#   'NDSN',
#   'HFWA',
#   'XPOF',
#   'PSTX',
#   'BRP',
#   'HCAT',
#   'ATSG',
#   'PGR',
#   'IMAX',
#   'ENFN',
#   'TWO',
#   'PFBC',
#   'SGHC',
#   'CDAY',
#   'LPRO',
#   'ORA',
#   'KNTK',
#   'CATY',
#   'INVA',
#   'MLKN',
#   'EWBC',
#   'WST',
#   'SCHW',
#   'SD',
#   'CIO',
#   'AVAV',
#   'BWA',
#   'JXN',
#   'ALE',
#   'CTOS',
#   'FVCB',
#   'VERA',
#   'UBSI',
#   'NAT',
#   'GCO',
#   'NRDY',
#   'MTX',
#   'AVXL',
#   'STGW',
#   'SGAFT',
#   'EGBN',
#   'GWW',
#   'AWK',
#   'VSEC',
#   'ERIE',
#   'BKR',
#   'RCEL',
#   'BARK',
#   'DX',
#   'SCPH',
#   'WKHS',
#   'F',
#   'FDMT',
#   'MDC',
#   'RMAX',
#   'CTVA',
#   'BLMN',
#   'OCFC',
#   'AGX',
#   'BFAM',
#   'JRVR',
#   'PLXS',
#   'PWSC',
#   'CURV',
#   'OLP',
#   'SCSC',
#   'CNS',
#   'ACRS',
#   'HA',
#   'GLW',
#   'FENC',
#   'DSP',
#   'ROK',
#   'WWD',
#   'HEAR',
#   'MOND',
#   'CRNX',
#   'CBOE',
#   'LMND',
#   'EWCZ',
#   'MDXG',
#   'GLBE',
#   'MD',
#   'DJCO',
#   'AKR',
#   'ACCO',
#   'OMC',
#   'BHB',
#   'OPFI',
#   'KO',
#   'EXPD',
#   'RYI',
#   'ATGE',
#   'ESNT',
#   'CBRE',
#   'CEG',
#   'VVI',
#   'NGM',
#   'AKAM',
#   'NQH4',
#   'LRMR',
#   'HSY',
#   'ORIC',
#   'SCS',
#   'TRUE',
#   'SOUN',
#   'CEVA',
#   'WING',
#   'FBIN',
#   'CRAI',
#   'ROVR',
#   'MYRG',
#   'CBU',
#   'NVAX',
#   'AVTE',
#   'ONB',
#   'CCEP',
#   'PDFS',
#   'PTC',
#   'PPL',
#   'CLSK',
#   'ASAN',
#   'KFY',
#   'CRGE',
#   'MED',
#   'NDAQ',
#   'DRI',
#   'KNF',
#   'USCB',
#   'FTCI',
#   'ALL',
#   'SYY',
#   'AON',
#   'NVGS',
#   'TEX',
#   'SPWH',
#   'CENX',
#   'FISI',
#   'ARDX',
#   'ASUR',
#   'HYLN',
#   'PRTA',
#   'CI',
#   'KRMD',
#   'RLJ',
#   'SSP',
#   'SAFE',
#   'MODG',
#   'MUR',
#   'LOGI',
#   'CSTM',
#   'PRK',
#   'MXCT',
#   'T',
#   'UNH',
#   'SR',
#   'SWK',
#   'SQ',
#   'GCBC',
#   'MEG',
#   'APP',
#   'TCBX',
#   '-',
#   'GRWG',
#   'LW',
#   'VHI',
#   'SHYF',
#   'IVAC',
#   'SKYT',
#   'TRN',
#   'YOU',
#   'RYTM',
#   'ETD',
#   'RACE',
#   'SFL',
#   'EA',
#   'ALPN',
#   'IVT',
#   'VABK',
#   'GCI',
#   'CTGO',
#   'RXRX',
#   'TTSH',
#   'WNC',
#   'NRC',
#   'WLLBW',
#   'CINF',
#   'SBT',
#   'BCO',
#   'JELD',
#   'GTN',
#   'FORR',
#   'SOI',
#   'COHU',
#   'PRO',
#   'SPOK',
#   'GH',
#   'SHOP',
#   'FTDR',
#   'EUR',
#   'CTKB',
#   'UTMD',
#   'HZO',
#   'STRA',
#   'PHAT',
#   'CDP',
#   'XRX',
#   'NJR',
#   'GPN',
#   'ORLY',
#   'ACET',
#   'SAVA',
#   'RPHM',
#   'ATRO',
#   'CPK',
#   'MAX',
#   'LOW',
#   'UFCS',
#   'MRTX',
#   'ARRY',
#   'ABBNY',
#   'TARO',
#   'DVA',
#   'LNW',
#   'MLI',
#   'MLM',
#   'CLS',
#   'VCTR',
#   'AXL',
#   'CNOB',
#   'NRG',
#   'ALXO',
#   'KOD',
#   'MSEX',
#   'RYZB',
#   'HLMN',
#   'HNI',
#   'SUM',
#   'DTC',
#   'CZR',
#   'GLNG',
#   'TK',
#   'HOUS',
#   'MCBC',
#   'OMER',
#   'CENT',
#   'TRTX',
#   'ABUS',
#   'AMPY',
#   'POOL',
#   'AFCG',
#   'NHI',
#   'OCUL',
#   'FSBC',
#   'STLA',
#   'ESH4',
#   'AXSM',
#   'CSV',
#   'EXR',
#   'CADE',
#   'DBX',
#   'FCPT',
#   'OSIS',
#   'PGRE',
#   'ATRA',
#   'VTRS',
#   'EXLS',
#   'CIVI',
#   'DENN',
#   'TYL',
#   'ARLO',
#   'PL',
#   'SSB',
#   'FI',
#   'ESMT',
#   'HMN',
#   'MBWM',
#   'GBX',
#   'MATX',
#   'XTSLA',
#   'UNFI',
#   'RBBN',
#   'FLNC',
#   'PDLB',
#   'DSKE',
#   'EFSC',
#   'BOC',
#   'CHCT',
#   'MLYS',
#   'BFS',
#   'PUBM',
#   'IMMR',
#   'CHGG',
#   'DXLG',
#   'BSVN',
#   'CRDO',
#   'KIM',
#   'GE',
#   'PFSI',
#   'QIPT',
#   'VERI',
#   'SCHL',
#   'ENPH',
#   'BVN',
#   'PNRG',
#   'PLD',
#   'BLKB',
#   'CCNE',
#   'WK',
#   'SAGE',
#   'USPH',
#   'FCF',
#   'BKSY',
#   'MNST',
#   'LSPD',
#   'TXRH',
#   'BRCC',
#   'AMBC',
#   'IHRT',
#   'MSCI',
#   'VZIO',
#   'PRVA',
#   'KLXE',
#   'ATKR',
#   'KW',
#   'FLWS',
#   'ANNX',
#   'WM',
#   'RLAY',
#   'IMKTA',
#   'QSI',
#   'PFIS',
#   'UFPI',
#   'CPRX',
#   'IPSC',
#   'INTC',
#   'PMT',
#   'BKD',
#   'SDRL',
#   'MFA',
#   'BOX',
#   'SPXC',
#   'NWS',
#   'EGY',
#   'NKTX',
#   'ACHR',
#   'DC',
#   'BASE',
#   'MYGN',
#   'ODP',
#   'ESTC',
#   'KODK',
#   'XHR',
#   'APA',
#   'CAD',
#   'DECK',
#   'AMPS',
#   'UIS',
#   'BBWI',
#   'MO',
#   'SLDP',
#   'AHH',
#   'PCB',
#   'WGO',
#   'HI',
#   'HD',
#   'MSI',
#   'CUTR',
#   'STBA',
#   'WSFS',
#   'CDRE',
#   'HTBI',
#   'WOW',
#   'ABNB',
#   'SMMF',
#   'UNF',
#   'SEAT',
#   'LXU',
#   'GOGL',
#   'CLW',
#   'TMHC',
#   'TITN',
#   'TMDX',
#   'RBB',
#   'CMCSA',
#   'EVRI',
#   'FPI',
#   'GBIO',
#   'YELP',
#   'ASO',
#   'SNCY',
#   'DLX',
#   'ROG',
#   'STRL',
#   'VCYT',
#   'SMBC',
#   'SSD',
#   'OPTN',
#   'HY',
#   'RXT',
#   'TNK',
#   'XERS',
#   'FIVN',
#   'VTLE',
#   'ADP',
#   'EP',
#   'BBY',
#   'MGY',
#   'MLAB',
#   'SBH',
#   'GKOS',
#   'IBP',
#   'TOWN',
#   'ZYME',
#   'REZI',
#   'CDLX',
#   'MITK',
#   'SJW',
#   'TBPH',
#   'SP',
#   'FCBC',
#   'PRTS',
#   'ADI',
#   'GPI',
#   'PTLO',
#   'VTYX',
#   'PXD',
#   'ATNI',
#   'ME',
#   'MODN',
#   'MDRX',
#   'HUBB',
#   'IBM',
#   'MPLN',
#   'MNSB',
#   'NSSC',
#   'PNW',
#   'YEXT',
#   'AX',
#   'OVID',
#   'HSTM',
#   'HL',
#   'APG',
#   'VRNT',
#   'DDS',
#   'MFC',
#   'METC',
#   'WALD',
#   'ESS',
#   'LAND',
#   'ACIC',
#   'EAF',
#   'AGS',
#   'ELME',
#   'DKS',
#   'CVLG',
#   'VOXX',
#   'WTW',
#   'BOH',
#   'RIOT',
#   'CCL',
#   'AEHR',
#   'AAPL',
#   'AZO',
#   'BDX',
#   'KRYS',
#   'TFIN',
#   'SNOW',
#   'WOR',
#   'ATI',
#   'HTH',
#   'LTC',
#   'NVTA',
#   'FLUT',
#   'UHT',
#   'ADTN',
#   'DIS',
#   'CRDA',
#   'RPAY',
#   'GIS',
#   'GMRE',
#   'SMRT',
#   'PBFS',
#   'OFLX',
#   'BGFV',
#   'WIX',
#   'PCG',
#   'EMR',
#   'MVIS',
#   'BSRR',
#   'STER',
#   'CBNK',
#   'MOGA',
#   'ABM',
#   'UHS',
#   'HBCP',
#   'CVCO',
#   'ACRV',
#   'PSTG',
#   'PIII',
#   'CDW',
#   'JAKK',
#   'RUSHA',
#   'PARA',
#   'PINS',
#   'HBI',
#   'CCOI',
#   'REI',
#   'NSTG',
#   'FFIV',
#   'ARCT',
#   'OB',
#   'POWL',
#   'NUS',
#   'LGIH',
#   'PRST',
#   'FFIN',
#   'BIG',
#   'ALKS',
#   'FE',
#   'CALM',
#   'CRS',
#   'CBZ',
#   'UBS',
#   'CRL',
#   'SMAR',
#   'DRQ',
#   'PCYO',
#   'OFIX',
#   'CHCO',
#   'GEL',
#   'TSN',
#   'BFB',
#   'NR',
#   'AZTA',
#   'BLDE',
#   'SQSP',
#   'EGHT',
#   'PSN',
#   'HNRG',
#   'TM',
#   'PAHC',
#   'LNT',
#   'CRVL',
#   'CELC',
#   'WRB',
#   'UMH',
#   'PD',
#   'FRT',
#   'CME',
#   'MLR',
#   'CRCT',
#   'GCMG',
#   'NKLA',
#   'SIRI',
#   'WEST',
#   'AMP',
#   'MYE',
#   'EG',
#   'VGR',
#   'TWKS',
#   'TENB',
#   'AIV',
#   'EFC',
#   'EHTH',
#   'HLT',
#   'LIVN',
#   'EQR',
#   'RAMP',
#   'KAMN',
#   'FA',
#   'EW',
#   'STOK',
#   'MARA',
#   'SKX',
#   'HOLI',
#   'JBL',
#   'VST',
#   'AESI',
#   'FET',
#   'BUSE',
#   'SGHT',
#   'URNM',
#   'NRIX',
#   'ADUS',
#   'VRA',
#   'PRDO',
#   'ULH',
#   'SABR',
#   'CTXR',
#   'TSLA',
#   'KTB',
#   'CGEM',
#   'PCOR',
#   'ODFL',
#   'HLIO',
#   'ENR',
#   'HAS',
#   'BFC',
#   'DDD',
#   'CXW',
#   'AROC',
#   'CAKE',
#   'FNKO',
#   'RGCO',
#   'DOV',
#   'OMGA',
#   'BHRB',
#   'FOUR',
#   'ALTM',
#   'FNLC',
#   'SHOO',
#   'ASTE',
#   'KRT',
#   'INDB',
#   'FRPH',
#   'EAT',
#   'KGS',
#   'IRBT',
#   'SM',
#   'TDG',
#   'EIX',
#   'BAM',
#   'IOVA',
#   'MEI',
#   'OSW',
#   'ESQ',
#   'AIRS',
#   'PRTH',
#   'FIX',
#   'CAL',
#   'FORM',
#   'VRE',
#   'VOR',
#   'ARCB',
#   'SBCF',
#   'MURA',
#   'BLDR',
#   'PNC',
#   'SFNC',
#   'RYAM',
#   'HOPE',
#   'CSWC',
#   'TRI',
#   'ACAD',
#   'SPWR',
#   'CZNC',
#   'ZETA',
#   'VYGR',
#   'RTYH4',
#   'PFG',
#   'NEE',
#   'MRNS',
#   'LH',
#   'PACK',
#   'FLL',
#   'ALKT',
#   'TALO',
#   'PJT',
#   'VPG',
#   'CRWD',
#   'GWRE',
#   'CRK',
#   'NU',
#   'HUM',
#   'EYPT',
#   'SFIX',
#   'TNYA',
#   'OSBC',
#   'IDXX',
#   'STHO',
#   'EL',
#   'AVO',
#   'WFRD',
#   'PNFP',
#   'KD',
#   'VRNS',
#   'PTSI',
#   'TRIP',
#   'ESE',
#   'TWOU',
#   'BBW',
#   'KVUE',
#   'PLOW',
#   'RELY',
#   'SMTC',
#   'CARM',
#   'CDNS',
#   'BIGC',
#   'VRCA',
#   'DOCU',
#   'ORGO',
#   'INGN',
#   'ATEX',
#   'DT',
#   'CRSP',
#   'RDVT',
#   'TPR',
#   'MCRB',
#   'KHC',
#   'BFLY',
#   'VREX',
#   'NET',
#   'RY',
#   'SWTX',
#   'PLL',
#   'BECN',
#   'MPC',
#   'ABR',
#   'KEYS',
#   'RPD',
#   'SCWO',
#   'BATRA',
#   'CHMG',
#   'CHRW',
#   'SEAS',
#   'IFF',
#   'GPMT',
#   'BIO',
#   'JBGS',
#   'INCY',
#   'HCKT',
#   'FBNC',
#   'IKNA',
#   'FDP',
#   'ICSUAGD',
#   'BE',
#   'STAA',
#   'JBHT',
#   'EME',
#   'DYN',
#   'NEOG',
#   'WVE',
#   'MODV',
#   'ACIW',
#   'DMRC',
#   'LOVE',
#   'SYBT',
#   'BEN',
#   'BR',
#   'LIND',
#   'VMEO',
#   'CHD',
#   'BLX',
#   'ELV',
#   'ENTA',
#   'ULCC',
#   'EQH',
#   'HST',
#   'WY',
#   'SMCI',
#   'HIMS',
#   'ACEL',
#   'SMTI',
#   'LNZA',
#   'NAPA',
#   'NE',
#   'PDSB',
#   'BLFS',
#   'TPIC',
#   'SOVO',
#   'UPST',
#   'BV',
#   'NWN',
#   'NHC',
#   'IR',
#   'GLUE',
#   'NWSA',
#   'QUAD',
#   'KIND',
#   'XMTR',
#   'UUUU',
#   'CARR',
#   'NTST',
#   'TG',
#   'JBI',
#   'BPRN',
#   'SASR',
#   'LII',
#   'OIS',
#   'RCKY',
#   'NRGV',
#   'ANDE',
#   'SEM',
#   'SANM',
#   'EQT',
#   'WTTR',
#   'TCN',
#   'REGN',
#   'CHTR',
#   'SMHI',
#   'MSFUT',
#   'APAM',
#   'MAS',
#   'AMAT',
#   'TIO',
#   'SHEN',
#   'ZWS',
#   'DV',
#   'BXC',
#   'ZIP',
#   'AMRK',
#   'ITI',
#   'EOSE',
#   'MLIFT',
#   'TGNA',
#   'FDBC',
#   'KTOS',
#   'PMTS',
#   'MKC',
#   'ROAD',
#   'ARKO',
#   'STEL',
#   'BXP',
#   'NATR',
#   'PRM',
#   'INSE',
#   'WS',
#   'GOOG',
#   'CMG',
#   'NVRI',
#   'VKTX',
#   'ITW',
#   'DOMO',
#   'DNLI',
#   'TH',
#   'PRI',
#   'QCRH',
#   'INFN',
#   'NMRA',
#   'AKRO',
#   'ARE',
#   'Z',
#   'ANSS',
#   'LEU',
#   'TIMB',
#   'ROCK',
#   'IRON',
#   'HII',
#   'ALTG',
#   'HONE',
#   'NTB',
#   'STEP',
#   'LCTX',
#   'OMI',
#   'ADRO',
#   'NC',
#   'FC',
#   'URGN',
#   'TRC',
#   'MBIN',
#   'PLYM',
#   'ERII',
#   'NREF',
#   'MOS',
#   'SPTN',
#   'ATEN',
#   'LHX',
#   'LWLG',
#   'VIGL',
#   'UAL',
#   'SSTI',
#   'JKHY',
#   'AEIS',
#   'GEHC',
#   'BG',
#   'SANA',
#   'BTAI',
#   'LYV',
#   'NKSH',
#   'NEO',
#   'HCA',
#   'TTEC',
#   'AUR',
#   'CMCL',
#   'ANGO',
#   'SNDX',
#   'ONEW',
#   ...})

# %%
stocks_ticker_set = all_stock_set

# %%
growth_stocks_df = pd.DataFrame()
growth_stocks_df['Symbol'] = list(stocks_ticker_set)
growth_stocks_df = growth_stocks_df.set_index(['Symbol'])
growth_stocks_df.index = growth_stocks_df.index.drop_duplicates()
# drop known junk symbols from the data feed
junk = ['MSFUT', 'GEFB', 'METCV', 'SGAFT', 'NQH4', 'XTSLA', '-', 'PDLI', 'ADRO', 'ICSUAGD', 'BFB', 'GTXI', 'P5N994', 'LGFB', 'MLIFT', 'ESH4', 'LGFA', 'MOGA', 'PBRA', 'BRKB', 'RTYH4', '\xa0', 'CRDA']
growth_stocks_df.index = growth_stocks_df.index.drop(junk)
growth_stocks_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [ASB, CIM, SEER, JANX, DOW, GDYN, LCNB, ARTNA, MNTK, SITC, AWR, WERN, IAS, GEVO, PKBK, PAGS, BTBT, FSLR, EYEN, GTLB, WRK, TDY, SONO, MLP, TARS, SPT, ATLC, CXM, CHRS, IPI, FLYW, SBGI, GSHD, CCSI, BITO, IOT, LNN, TILE, MTRN, CLMB, ECL, OTTR, DAL, OKE, AMT, CUBI, IMGN, DORM, MET, PRAA, MRK, COFS, VCEL, WSR, CVBF, HQI, DCPH, DGICA, COOK, SKIN, KALU, REG, ONL, CDZI, GDDY, BKU, AMN, BBUC, AVAH, DZSI, UNTY, PEP, TDUP, FCEL, ZURA, JNJ, ACRE, LNTH, SRRK, MMYT, VTOL, DO, DLTH, NBN, HRT, NOG, SUPN, GLT, CPSS, MRTN, ARWR, MGNI, TGH, SAMG, PETS, TSE, KMX, BLK, ANET, POWW, ...]
#
# [2650 rows x 0 columns]

# %%
growth_stocks_df.to_csv(f'data/data-3rd-party/{all_stocks_file}')

# %% [markdown]
# ## Prepare broad market indicies

# %%
# Capture S&P500, NASDAQ100 and Russell 200 indexes and their equal weighted counter parts
# As well as VIX volatility index, DYX US Dollar index, TNX US 12 Weeks Treasury Yield, 5 Years Treasury Yield and 10 Year Treasuries Yield
broad_market_indicies = '^SPX ^SPXEW ^NDX ^NDXE ^RUT ^R2ESC ^VIX DX-Y.NYB ^IRX ^FVX ^TNX'

# %%
broad_market = yf.download(broad_market_indicies, period='max', group_by='tickers')
broad_market
# Out:
# [*********************100%%**********************]  11 of 11 completed
#                  ^R2ESC                                                      \
#                    Open         High          Low        Close    Adj Close
# Date
# 1927-12-30          NaN          NaN          NaN          NaN          NaN
# 1928-01-03          NaN          NaN          NaN          NaN          NaN
# 1928-01-04          NaN          NaN          NaN          NaN          NaN
# 1928-01-05          NaN          NaN          NaN          NaN          NaN
# 1928-01-06          NaN          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# 2024-01-29          NaN          NaN          NaN          NaN          NaN
# 2024-01-30          NaN          NaN          NaN          NaN          NaN
# 2024-01-31          NaN          NaN          NaN          NaN          NaN
# 2024-02-01          NaN          NaN          NaN          NaN          NaN
# 2024-02-02  4188.051758  4188.051758  4166.918457  4182.222168  4182.222168
#
#                          ^NDXE                                         ...  \
#            Volume         Open         High          Low        Close  ...
# Date                                                                   ...
# 1927-12-30    NaN          NaN          NaN          NaN          NaN  ...
# 1928-01-03    NaN          NaN          NaN          NaN          NaN  ...
# 1928-01-04    NaN          NaN          NaN          NaN          NaN  ...
# 1928-01-05    NaN          NaN          NaN          NaN          NaN  ...
# 1928-01-06    NaN          NaN          NaN          NaN          NaN  ...
# ...           ...          ...          ...          ...          ...  ...
# 2024-01-29    NaN  7265.220215  7339.299805  7262.799805  7339.000000  ...
# 2024-01-30    NaN  7300.240234  7312.680176  7285.680176  7294.640137  ...
# 2024-01-31    NaN  7242.250000  7289.140137  7183.790039  7190.290039  ...
# 2024-02-01    NaN  7214.520020  7276.729980  7179.700195  7274.620117  ...
# 2024-02-02    0.0          NaN          NaN          NaN          NaN  ...
#
#              ^TNX                                 ^SPX               \
#               Low  Close Adj Close Volume         Open         High
# Date
# 1927-12-30    NaN    NaN       NaN    NaN    17.660000    17.660000
# 1928-01-03    NaN    NaN       NaN    NaN    17.760000    17.760000
# 1928-01-04    NaN    NaN       NaN    NaN    17.719999    17.719999
# 1928-01-05    NaN    NaN       NaN    NaN    17.549999    17.549999
# 1928-01-06    NaN    NaN       NaN    NaN    17.660000    17.660000
# ...           ...    ...       ...    ...          ...          ...
# 2024-01-29  4.089  4.091     4.091    0.0  4892.950195  4929.310059
# 2024-01-30  4.041  4.059     4.059    0.0  4925.890137  4931.089844
# 2024-01-31  3.944  3.967     3.967    0.0  4899.189941  4906.750000
# 2024-02-01  3.817  3.863     3.863    0.0  4861.109863  4906.970215
# 2024-02-02  3.887  4.026     4.026    0.0  4916.060059  4930.649902
#
#
#                     Low        Close    Adj Close        Volume
# Date
# 1927-12-30    17.660000    17.660000    17.660000  0.000000e+00
# 1928-01-03    17.760000    17.760000    17.760000  0.000000e+00
# 1928-01-04    17.719999    17.719999    17.719999  0.000000e+00
# 1928-01-05    17.549999    17.549999    17.549999  0.000000e+00
# 1928-01-06    17.660000    17.660000    17.660000  0.000000e+00
# ...                 ...          ...          ...           ...
# 2024-01-29  4887.399902  4927.930176  4927.930176  3.525160e+09
# 2024-01-30  4916.270020  4924.970215  4924.970215  3.836130e+09
# 2024-01-31  4845.149902  4845.649902  4845.649902  4.696120e+09
# 2024-02-01  4853.520020  4906.189941  4906.189941  4.386090e+09
# 2024-02-02  4907.990234  4929.529785  4929.529785  6.965062e+08
#
# [24330 rows x 66 columns]

# %%
# broad_market.to_csv('data/broad_market.csv.bz2', index='Date')

# %%
bm_file = 'data/data-3rd-party/broad_market.parquet'
broad_market.to_parquet(bm_file)

# %%
bm = pd.read_parquet(bm_file)

# %%
bm
# Out:
#                  ^R2ESC                                                      \
#                    Open         High          Low        Close    Adj Close
# Date
# 1927-12-30          NaN          NaN          NaN          NaN          NaN
# 1928-01-03          NaN          NaN          NaN          NaN          NaN
# 1928-01-04          NaN          NaN          NaN          NaN          NaN
# 1928-01-05          NaN          NaN          NaN          NaN          NaN
# 1928-01-06          NaN          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# 2024-01-29          NaN          NaN          NaN          NaN          NaN
# 2024-01-30          NaN          NaN          NaN          NaN          NaN
# 2024-01-31          NaN          NaN          NaN          NaN          NaN
# 2024-02-01          NaN          NaN          NaN          NaN          NaN
# 2024-02-02  4188.051758  4188.051758  4166.918457  4182.222168  4182.222168
#
#                          ^NDXE                                         ...  \
#            Volume         Open         High          Low        Close  ...
# Date                                                                   ...
# 1927-12-30    NaN          NaN          NaN          NaN          NaN  ...
# 1928-01-03    NaN          NaN          NaN          NaN          NaN  ...
# 1928-01-04    NaN          NaN          NaN          NaN          NaN  ...
# 1928-01-05    NaN          NaN          NaN          NaN          NaN  ...
# 1928-01-06    NaN          NaN          NaN          NaN          NaN  ...
# ...           ...          ...          ...          ...          ...  ...
# 2024-01-29    NaN  7265.220215  7339.299805  7262.799805  7339.000000  ...
# 2024-01-30    NaN  7300.240234  7312.680176  7285.680176  7294.640137  ...
# 2024-01-31    NaN  7242.250000  7289.140137  7183.790039  7190.290039  ...
# 2024-02-01    NaN  7214.520020  7276.729980  7179.700195  7274.620117  ...
# 2024-02-02    0.0          NaN          NaN          NaN          NaN  ...
#
#              ^TNX                                 ^SPX               \
#               Low  Close Adj Close Volume         Open         High
# Date
# 1927-12-30    NaN    NaN       NaN    NaN    17.660000    17.660000
# 1928-01-03    NaN    NaN       NaN    NaN    17.760000    17.760000
# 1928-01-04    NaN    NaN       NaN    NaN    17.719999    17.719999
# 1928-01-05    NaN    NaN       NaN    NaN    17.549999    17.549999
# 1928-01-06    NaN    NaN       NaN    NaN    17.660000    17.660000
# ...           ...    ...       ...    ...          ...          ...
# 2024-01-29  4.089  4.091     4.091    0.0  4892.950195  4929.310059
# 2024-01-30  4.041  4.059     4.059    0.0  4925.890137  4931.089844
# 2024-01-31  3.944  3.967     3.967    0.0  4899.189941  4906.750000
# 2024-02-01  3.817  3.863     3.863    0.0  4861.109863  4906.970215
# 2024-02-02  3.887  4.026     4.026    0.0  4916.060059  4930.649902
#
#
#                     Low        Close    Adj Close        Volume
# Date
# 1927-12-30    17.660000    17.660000    17.660000  0.000000e+00
# 1928-01-03    17.760000    17.760000    17.760000  0.000000e+00
SORED, ENDORSED, ISSUED, SOLD OR PROMOTED BY BLOOMBERG, BLACKROCK INDEX SERVICES, LLC, CBOE GLOBAL INDICES, LLC, COHEN & STEERS, EUROPEAN PUBLIC REAL ESTATE ASSOCIATION (“EPRA® ”), FTSE INTERNATIONAL LIMITED (“FTSE”), ICE DATA INDICES, LLC, NSE INDICES LTD, JPMORGAN, JPX GROUP, LONDON STOCK EXCHANGE GROUP (“LSEG”), MSCI INC., MARKIT INDICES LIMITED, MORNINGSTAR, INC., NASDAQ, INC., NATIONAL ASSOCIATION OF REAL ESTATE INVESTMENT TRUSTS (“NAREIT”), NIKKEI, INC., RUSSELL, S&P DOW JONES INDICES LLC OR STOXX LTD. NONE OF THESE COMPANIES MAKE ANY REPRESENTATION REGARDING THE ADVISABILITY OF INVESTING IN THE FUNDS. WITH THE EXCEPTION OF BLACKROCK INDEX SERVICES, LLC, WHO IS AN AFFILIATE, BLACKROCK INVESTMENTS, LLC IS NOT AFFILIATED WITH THE COMPANIES LISTED ABOVE. NEITHER FTSE, LSEG, NOR NAREIT MAKES ANY WARRANTY REGARDING THE FTSE NAREIT EQUITY REITS INDEX, FTSE NAREIT ALL RESIDENTIAL CAPPED INDEX OR FTSE NAREIT ALL MORTGAGE CAPPED INDEX. NEITHER FTSE, EPRA, LSEG, NOR NAREIT MAKES ANY WARRANTY REGARDING THE FTSE EPRA NAREIT DEVELOPED EX-U.S. INDEX, FTSE EPRA NAREIT DEVELOPED GREEN TARGET INDEX OR FTSE EPRA NAREIT GLOBAL REITS INDEX. “FTSE®” IS A TRADEMARK OF LONDON STOCK EXCHANGE GROUP COMPANIES AND IS USED BY FT ...
# ['\xa0']: Exception('\xa0: No timezone found, symbol may be delisted')
# ['CRDA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1925-02-25 -> 2024-02-02)')
#                   VTS                                                        \
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 1962-01-02        NaN        NaN        NaN        NaN        NaN       NaN
# 1962-01-03        NaN        NaN        NaN        NaN        NaN       NaN
# 1962-01-04        NaN        NaN        NaN        NaN        NaN       NaN
# 1962-01-05        NaN        NaN        NaN        NaN        NaN       NaN
# 1962-01-08        NaN        NaN        NaN        NaN        NaN       NaN
# ...               ...        ...        ...        ...        ...       ...
# 2024-01-29  21.450001  21.670000  21.020000  21.650000  21.650000  152800.0
# 2024-01-30  21.490000  21.775999  21.360001  21.730000  21.730000   83900.0
# 2024-01-31  21.780001  21.780001  20.990000  21.010000  21.010000  222100.0
# 2024-02-01  21.110001  21.260000  20.660000  20.709999  20.709999  181000.0
# 2024-02-02  20.620001  20.620001  19.629999  19.995001  19.995001  111745.0
#
#             PGEN                      ...       POWI                        \
#             Open  High    Low  Close  ...        Low      Close  Adj Close
# Date                                  ...
# 1962-01-02   NaN   NaN    NaN    NaN  ...        NaN        NaN        NaN
# 1962-01-03   NaN   NaN    NaN    NaN  ...        NaN        NaN        NaN
# 1962-01-04   NaN   NaN    NaN    NaN  ...        NaN        NaN        NaN
# 1962-01-05   NaN   NaN    NaN    NaN  ...        NaN        NaN        NaN
# 1962-01-08   NaN   NaN    NaN    NaN  ...        NaN        NaN        NaN
#            BA     0.190931   0.823045   0.837449   0.823045   0.837449
#            CAT    0.476659   1.604167   1.619792   1.588542   1.604167
#            CNP    0.334449  10.783375  10.865333  10.783375   0.000000
#            CVX    0.339417   3.296131   3.296131   3.244048   0.000000
# ...                    ...        ...        ...        ...        ...
# 2024-02-02 ZVIA   1.640000   1.640000   1.690000   1.640000   1.670000
#            ZVRA   5.840000   5.840000   5.920000   5.770000   5.900000
#            ZWS   30.180000  30.180000  30.250000  29.908400  29.950001
#            ZYME  10.920000  10.920000  11.060000  10.800000  10.940000
#            ZYXI  11.570000  11.570000  11.670000  11.500000  11.500000
#
#                    Volume
# Date
# 1962-01-02 AEP     5800.0
#            BA    352350.0
#            CAT   163200.0
#            CNP    13879.0
#            CVX   105840.0
# ...                   ...
# 2024-02-02 ZVIA   28259.0
#            ZVRA   31833.0
#            ZWS   135475.0
#            ZYME   50296.0
#            ZYXI   60433.0
#
# [13476911 rows x 6 columns]

# %%
df2.index
# Out:
# MultiIndex([('1962-01-02',  'AEP'),
#             ('1962-01-02',   'BA'),
#             ('1962-01-02',  'CAT'),
#             ('1962-01-02',  'CNP'),
#             ('1962-01-02',  'CVX'),
#             ('1962-01-02',  'DIS'),
#             ('1962-01-02',  'DTE'),
#             ('1962-01-02',   'ED'),
#             ('1962-01-02',   'FL'),
#             ('1962-01-02',   'GD'),
#             ...
#             ('2024-02-02',   'ZS'),
#             ('2024-02-02',  'ZTS'),
#             ('2024-02-02', 'ZUMZ'),
#             ('2024-02-02',  'ZUO'),
#             ('2024-02-02', 'ZURA'),
#             ('2024-02-02', 'ZVIA'),
#             ('2024-02-02', 'ZVRA'),
#             ('2024-02-02',  'ZWS'),
#             ('2024-02-02', 'ZYME'),
#             ('2024-02-02', 'ZYXI')],
#            names=['Date', None], length=13476911)

# %%
df2.index.names = ['Date', 'Symbol']

# %%
df2 = df2.index.swaplevel(0)
# Out:
# MultiIndex([( 'AEP', '1962-01-02'),
#             (  'BA', '1962-01-02'),
#             ( 'CAT', '1962-01-02'),
#             ( 'CNP', '1962-01-02'),
#             ( 'CVX', '1962-01-02'),
#             ( 'DIS', '1962-01-02'),
#             ( 'DTE', '1962-01-02'),
#             (  'ED', '1962-01-02'),
#             (  'FL', '1962-01-02'),
#             (  'GD', '1962-01-02'),
#             ...
#             (  'ZS', '2024-02-02'),
#             ( 'ZTS', '2024-02-02'),
#             ('ZUMZ', '2024-02-02'),
#             ( 'ZUO', '2024-02-02'),
#             ('ZURA', '2024-02-02'),
#             ('ZVIA', '2024-02-02'),
#             ('ZVRA', '2024-02-02'),
#             ( 'ZWS', '2024-02-02'),
#             ('ZYME', '2024-02-02'),
#             ('ZYXI', '2024-02-02')],
#            names=['Symbol', 'Date'], length=13476911)

# %%
df2
# Out:
#                    Adj Close      Close       High        Low       Open  \
# Date       Symbol
# 1962-01-02 AEP      0.970557  34.312500  35.125000  34.312500   0.000000
#            BA       0.190931   0.823045   0.837449   0.823045   0.837449
#            CAT      0.476659   1.604167   1.619792   1.588542   1.604167
#            CNP      0.334449  10.783375  10.865333  10.783375   0.000000
#            CVX      0.339417   3.296131   3.296131   3.244048   0.000000
# ...                      ...        ...        ...        ...        ...
# 2024-02-02 ZVIA     1.640000   1.640000   1.690000   1.640000   1.670000
#            ZVRA     5.840000   5.840000   5.920000   5.770000   5.900000
#            ZWS     30.180000  30.180000  30.250000  29.908400  29.950001
#            ZYME    10.920000  10.920000  11.060000  10.800000  10.940000
#            ZYXI    11.570000  11.570000  11.670000  11.500000  11.500000
#
#                      Volume
# Date       Symbol
# 1962-01-02 AEP       5800.0
#            BA      352350.0
#            CAT     163200.0
#            CNP      13879.0
#            CVX     105840.0
# ...                     ...
# 2024-02-02 ZVIA     28259.0
#            ZVRA     31833.0
#            ZWS     135475.0
#            ZYME     50296.0
#            ZYXI     60433.0
#
# [13476911 rows x 6 columns]

# %%
df2 = df2.sort_index()
df2

# %%
# stock_price_data.to_csv(price_hist_file, index='Date')
df2.to_parquet(price_hist_file)

# %%
# stock_price_data_loaded = pd.read_csv(price_hist_file, header=[0, 1], index_col=0)
stock_price_data_loaded = pd.read_parquet(price_hist_file) #, filters=[("Symbol", "in", ['AEP', 'AAPL'])])
stock_price_data_loaded
# Out:
#                    Adj Close      Close       High        Low       Open  \
# Symbol Date
# A      1999-11-18  26.695686  31.473534  35.765381  28.612303  32.546494
#        1999-11-19  24.496334  28.880545  30.758226  28.478184  30.713518
#        1999-11-22  26.695686  31.473534  31.473534  28.657009  29.551144
#        1999-11-23  24.268808  28.612303  31.205294  28.612303  30.400572
#        1999-11-24  24.913454  29.372318  29.998213  28.612303  28.701717
# ...                      ...        ...        ...        ...        ...
# ZYXI   2024-01-29  11.410000  11.410000  11.550000  11.300000  11.350000
#        2024-01-30  11.760000  11.760000  11.950000  11.370000  11.370000
#        2024-01-31  11.840000  11.840000  12.070000  11.700000  11.700000
#        2024-02-01  11.660000  11.660000  12.130000  11.640000  11.930000
#        2024-02-02  11.570000  11.570000  11.670000  11.500000  11.500000
#
#                        Volume
# Symbol Date
# A      1999-11-18  62546380.0
#        1999-11-19  15234146.0
#        1999-11-22   6577870.0
#        1999-11-23   5975611.0
#        1999-11-24   4843231.0
# ...                       ...
# ZYXI   2024-01-29    261900.0
#        2024-01-30    484200.0
#        2024-01-31    423600.0
#        2024-02-01    417600.0
#        2024-02-02     60433.0
#
# [13476911 rows x 6 columns]

# %%
stock_price_data_loaded.dropna()
# Out:
#                    Adj Close      Close       High        Low       Open  \
# Symbol Date
# A      1999-11-18  26.695686  31.473534  35.765381  28.612303  32.546494
#        1999-11-19  24.496334  28.880545  30.758226  28.478184  30.713518
#        1999-11-22  26.695686  31.473534  31.473534  28.657009  29.551144
#        1999-11-23  24.268808  28.612303  31.205294  28.612303  30.400572
#        1999-11-24  24.913454  29.372318  29.998213  28.612303  28.701717
# ...                      ...        ...        ...        ...        ...
# ZYXI   2024-01-29  11.410000  11.410000  11.550000  11.300000  11.350000
#        2024-01-30  11.760000  11.760000  11.950000  11.370000  11.370000
#        2024-01-31  11.840000  11.840000  12.070000  11.700000  11.700000
#        2024-02-01  11.660000  11.660000  12.130000  11.640000  11.930000
#        2024-02-02  11.570000  11.570000  11.670000  11.500000  11.500000
#
#                        Volume
# Symbol Date
# A      1999-11-18  62546380.0
#        1999-11-19  15234146.0
#        1999-11-22   6577870.0
#        1999-11-23   5975611.0
#        1999-11-24   4843231.0
# ...                       ...
# ZYXI   2024-01-29    261900.0
#        2024-01-30    484200.0
#        2024-01-31    423600.0
#        2024-02-01    417600.0
#        2024-02-02     60433.0
#
# [13476911 rows x 6 columns]

# %%
list(stock_price_data_loaded.index.levels[0])
# Out:
# ['A',
#  'AADI',
#  'AAL',
#  'AAN',
#  'AAON',
#  'AAPL',
#  'AAT',
#  'ABBNY',
#  'ABBV',
#  'ABCB',
#  'ABG',
#  'ABM',
#  'ABNB',
#  'ABR',
#  'ABT',
#  'ABUS',
#  'ABVX',
#  'ACA',
#  'ACAD',
#  'ACCD',
#  'ACCO',
#  'ACDC',
#  'ACEL',
#  'ACET',
#  'ACGL',
#  'ACHR',
#  'ACIC',
#  'ACIW',
#  'ACLS',
#  'ACLX',
#  'ACMR',
#  'ACN',
#  'ACNB',
#  'ACRE',
#  'ACRS',
#  'ACRV',
#  'ACT',
#  'ACTG',
#  'ACVA',
#  'ADBE',
#  'ADEA',
#  'ADI',
#  'ADM',
#  'ADMA',
#  'ADNT',
#  'ADP',
#  'ADPT',
#  'ADSK',
#  'ADTN',
#  'ADUS',
#  'ADV',
#  'AEE',
#  'AEHR',
#  'AEIS',
#  'AEL',
#  'AEO',
#  'AEP',
#  'AER',
#  'AES',
#  'AESI',
#  'AEVA',
#  'AFCG',
#  'AFL',
#  'AFRI',
#  'AFRM',
#  'AFYA',
#  'AGEN',
#  'AGIO',
#  'AGM',
#  'AGO',
#  'AGS',
#  'AGTI',
#  'AGX',
#  'AGYS',
#  'AHCO',
#  'AHH',
#  'AI',
#  'AIG',
#  'AIN',
#  'AIR',
#  'AIRS',
#  'AIT',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'AKR',
#  'AKRO',
#  'AKTS',
#  'AKYA',
#  'ALB',
#  'ALCO',
#  'ALDX',
#  'ALE',
#  'ALEC',
#  'ALEX',
#  'ALG',
#  'ALGN',
#  'ALGT',
#  'ALHC',
#  'ALIT',
#  'ALKS',
#  'ALKT',
#  'ALL',
#  'ALLE',
#  'ALLK',
#  'ALLO',
#  'ALLY',
#  'ALNT',
#  'ALPN',
#  'ALRM',
#  'ALRS',
#  'ALT',
#  'ALTG',
#  'ALTI',
#  'ALTM',
#  'ALTR',
#  'ALVR',
#  'ALX',
#  'ALXO',
#  'AMAL',
#  'AMAT',
#  'AMBA',
#  'AMBC',
#  'AMCR',
#  'AMCX',
#  'AMD',
#  'AME',
#  'AMEH',
#  'AMGN',
#  'AMK',
#  'AMKR',
#  'AMLX',
#  'AMN',
#  'AMNB',
#  'AMP',
#  'AMPH',
#  'AMPL',
#  'AMPS',
#  'AMPX',
#  'AMPY',
#  'AMR',
#  'AMRC',
#  'AMRK',
#  'AMRX',
#  'AMSF',
#  'AMSWA',
#  'AMT',
#  'AMTB',
#  'AMWD',
#  'AMWL',
#  'AMZN',
#  'ANAB',
#  'ANDE',
#  'ANET',
#  'ANF',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANNX',
#  'ANSS',
#  'AOMR',
#  'AON',
#  'AORT',
#  'AOS',
#  'AOSL',
#  'APA',
#  'APAM',
#  'APD',
#  'APG',
#  'APGE',
#  'APH',
#  'APLD',
#  'APLE',
#  'APLS',
#  'APO',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPN',
#  'APPS',
#  'APTV',
#  'ARAY',
#  'ARCB',
#  'ARCH',
#  'ARCO',
#  'ARCT',
#  'ARDX',
#  'ARE',
#  'ARES',
#  'ARI',
#  'ARIS',
#  'ARKO',
#  'ARL',
#  'ARLO',
#  'ARM',
#  'AROC',
#  'AROW',
#  'ARQT',
#  'ARR',
#  'ARRY',
#  'ARTNA',
#  'ARVN',
#  'ARWR',
#  'ASAN',
#  'ASB',
#  'ASC',
#  'ASGN',
#  'ASIX',
#  'ASLE',
#  'ASML',
#  'ASND',
#  'ASO',
#  'ASPN',
#  'ASRT',
#  'ASTE',
#  'ASTS',
#  'ASUR',
#  'ATEC',
#  'ATEN',
#  'ATEX',
#  'ATGE',
#  'ATI',
#  'ATKR',
#  'ATLC',
#  'ATLO',
#  'ATMU',
#  'ATNI',
#  'ATNM',
#  'ATO',
#  'ATOM',
#  'ATRA',
#  'ATRC',
#  'ATRI',
#  'ATRO',
#  'ATSG',
#  'ATXS',
#  'AUB',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AVA',
#  'AVAH',
#  'AVAV',
#  'AVB',
#  'AVD',
#  'AVDX',
#  'AVGO',
#  'AVIR',
#  'AVNS',
#  'AVNT',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVTE',
#  'AVXL',
#  'AVY',
#  'AWI',
#  'AWK',
#  'AWR',
#  'AX',
#  'AXGN',
#  'AXL',
#  'AXNX',
#  'AXON',
#  'AXP',
#  'AXSM',
#  'AZEK',
#  'AZN',
#  'AZO',
#  'AZTA',
#  'AZZ',
#  'B',
#  'BA',
#  'BAC',
#  'BALL',
#  'BALY',
#  'BAM',
#  'BANC',
#  'BAND',
#  'BANF',
#  'BANR',
#  'BARK',
#  'BASE',
#  'BATRA',
#  'BATRK',
#  'BAX',
#  'BBAI',
#  'BBCP',
#  'BBIO',
#  'BBSI',
#  'BBUC',
#  'BBW',
#  'BBWI',
#  'BBY',
#  'BCAB',
#  'BCBP',
#  'BCC',
#  'BCML',
#  'BCO',
#  'BCOV',
#  'BCPC',
#  'BCRX',
#  'BDC',
#  'BDN',
#  'BDX',
#  'BE',
#  'BEAM',
#  'BECN',
#  'BELFB',
#  'BEN',
#  'BFAM',
#  'BFC',
#  'BFH',
#  'BFLY',
#  'BFS',
#  'BFST',
#  'BG',
#  'BGC',
#  'BGFV',
#  'BGS',
#  'BGXX',
#  'BH',
#  'BHB',
#  'BHE',
#  'BHIL',
#  'BHLB',
#  'BHR',
#  'BHRB',
#  'BHVN',
#  'BIG',
#  'BIGC',
#  'BIIB',
#  'BIO',
#  'BIPC',
#  'BIRD',
#  'BIRK',
#  'BITO',
#  'BJRI',
#  'BK',
#  'BKD',
#  'BKE',
#  'BKH',
#  'BKKT',
#  'BKNG',
#  'BKR',
#  'BKSY',
#  'BKU',
#  'BL',
#  'BLBD',
#  'BLD',
#  'BLDE',
#  'BLDR',
#  'BLFS',
#  'BLFY',
#  'BLK',
#  'BLKB',
#  'BLMN',
#  'BLNK',
#  'BLUE',
#  'BLX',
#  'BMBL',
#  'BMEA',
#  'BMI',
#  'BMRC',
#  'BMY',
#  'BNL',
#  'BOC',
#  'BOH',
#  'BOOM',
#  'BOOT',
#  'BORR',
#  'BOWL',
#  'BOX',
#  'BPMC',
#  'BPRN',
#  'BR',
#  'BRBR',
#  'BRBS',
#  'BRCC',
#  'BRKL',
#  'BRO',
#  'BROS',
#  'BRP',
#  'BRSP',
#  'BRT',
#  'BRY',
#  'BRZE',
#  'BSIG',
#  'BSRR',
#  'BSVN',
#  'BSX',
#  'BTAI',
#  'BTBT',
#  'BTMD',
#  'BTU',
#  'BURL',
#  'BUSE',
#  'BV',
#  'BVN',
#  'BW',
#  'BWA',
#  'BWB',
#  'BWFG',
#  'BWMN',
#  'BX',
#  'BXC',
#  'BXMT',
#  'BXP',
#  'BY',
#  'BYND',
#  'BYON',
#  'BZH',
#  'C',
#  'CABA',
#  'CAC',
#  'CAD',
#  'CADE',
#  'CAG',
#  'CAH',
#  'CAKE',
#  'CAL',
#  'CALM',
#  'CALX',
#  'CAMT',
#  'CANO',
#  'CARA',
#  'CARE',
#  'CARG',
#  'CARM',
#  'CARR',
#  'CARS',
#  'CASH',
#  'CASS',
#  'CAT',
#  'CATC',
#  'CATO',
#  'CATY',
#  'CAVA',
#  'CB',
#  'CBAN',
#  'CBAY',
#  'CBL',
#  'CBNK',
#  'CBOE',
#  'CBRE',
#  'CBRL',
#  'CBT',
#  'CBU',
#  'CBZ',
#  'CCB',
#  'CCBG',
#  'CCEP',
#  'CCI',
#  'CCJ',
#  'CCL',
#  'CCNE',
#  'CCO',
#  'CCOI',
#  'CCRD',
#  'CCRN',
#  'CCS',
#  'CCSI',
#  'CDAY',
#  'CDE',
#  'CDLX',
#  'CDMO',
#  'CDNA',
#  'CDNS',
#  'CDP',
#  'CDRE',
#  'CDW',
#  'CDXS',
#  'CDZI',
#  'CE',
#  'CECO',
#  'CEG',
#  'CEIX',
#  'CELC',
#  'CELH',
#  'CENT',
#  'CENTA',
#  'CENX',
#  'CERE',
#  'CERS',
#  'CEVA',
#  'CF',
#  'CFB',
#  'CFFI',
#  'CFFN',
#  'CFG',
#  'CGEM',
#  'CHCO',
#  'CHCT',
#  'CHD',
#  'CHEF',
#  'CHGG',
#  'CHKP',
#  'CHMG',
#  'CHRD',
#  'CHRS',
#  'CHRW',
#  'CHTR',
#  'CHUY',
#  'CHX',
#  'CI',
#  'CIFR',
#  'CIM',
#  'CINF',
#  'CIO',
#  'CIVB',
#  'CIVI',
#  'CIX',
#  'CL',
#  'CLAR',
#  'CLB',
#  'CLBK',
#  'CLDT',
#  'CLDX',
#  'CLFD',
#  'CLMB',
#  'CLNE',
#  'CLPR',
#  'CLPT',
#  'CLS',
#  'CLSK',
#  'CLW',
#  'CLX',
#  'CMA',
#  'CMAX',
#  'CMBM',
#  'CMC',
#  'CMCL',
#  'CMCO',
#  'CMCSA',
#  'CME',
#  'CMG',
#  'CMI',
#  'CMP',
#  'CMPO',
#  'CMPR',
#  'CMPX',
#  'CMRE',
#  'CMS',
#  'CMT',
#  'CMTG',
#  'CMTL',
#  'CNC',
#  'CNDT',
#  'CNK',
#  'CNM',
#  'CNMD',
#  'CNNE',
#  'CNO',
#  'CNOB',
#  'CNP',
#  'CNS',
#  'CNSL',
#  'CNTY',
#  'CNX',
#  'CNXN',
#  'COCO',
#  'CODI',
#  'COF',
#  'COFS',
#  'COGT',
#  'COHU',
#  'COIN',
#  'COKE',
#  'COLB',
#  'COLL',
#  'COMM',
#  'COMP',
#  'COO',
#  'COOK',
#  'COOP',
#  'COP',
#  'COR',
#  'CORT',
#  'COST',
#  'COTY',
#  'COUR',
#  'CPB',
#  'CPE',
#  'CPF',
#  'CPK',
#  'CPRT',
#  'CPRX',
#  'CPS',
#  'CPSI',
#  'CPSS',
#  'CPT',
#  'CRAI',
#  'CRBG',
#  'CRBU',
#  'CRC',
#  'CRCT',
#  'CRDO',
#  'CRGE',
#  'CRGY',
#  'CRH',
#  'CRK',
#  'CRL',
#  'CRM',
#  'CRMD',
#  'CRMT',
#  'CRNC',
#  'CRNX',
#  'CRS',
#  'CRSP',
#  'CRSR',
#  'CRVL',
#  'CRWD',
#  'CSCO',
#  'CSGP',
#  'CSGS',
#  'CSR',
#  'CSTL',
#  'CSTM',
#  'CSTR',
#  'CSV',
#  'CSWC',
#  'CSWI',
#  'CSX',
#  'CTAS',
#  'CTBI',
#  'CTGO',
#  'CTKB',
#  'CTLP',
#  'CTLT',
#  'CTO',
#  'CTOS',
#  'CTRA',
#  'CTRE',
#  'CTS',
#  'CTSH',
#  'CTVA',
#  'CTXR',
#  'CUBI',
#  'CUE',
#  'CUK',
#  'CURV',
#  'CUTR',
#  'CVBF',
#  'CVCO',
#  'CVCY',
#  'CVGI',
#  'CVGW',
#  'CVI',
#  'CVLG',
#  'CVLT',
#  'CVLY',
#  'CVNA',
#  'CVRX',
#  'CVS',
#  'CVX',
#  'CWCO',
#  'CWH',
#  'CWK',
#  'CWST',
#  'CWT',
#  'CXM',
#  'CXW',
#  'CYBR',
#  'CYH',
#  'CYRX',
#  'CYTK',
#  'CZFS',
#  'CZNC',
#  'CZR',
#  'D',
#  'DAKT',
#  'DAL',
#  'DAN',
#  'DASH',
#  'DAWN',
#  'DB',
#  'DBI',
#  'DBRG',
#  'DBX',
#  'DC',
#  'DCGO',
#  'DCO',
#  'DCOM',
#  'DCPH',
#  'DD',
#  'DDD',
#  'DDOG',
#  'DDS',
#  'DE',
#  'DEA',
#  'DECK',
#  'DEI',
#  'DELL',
#  'DENN',
#  'DFH',
#  'DFIN',
#  'DFLI',
#  'DFS',
#  'DG',
#  'DGICA',
#  'DGII',
#  'DGX',
#  'DH',
#  'DHC',
#  'DHI',
#  'DHIL',
#  'DHR',
#  'DHT',
#  'DHX',
#  'DIN',
#  'DIOD',
#  'DIS',
#  'DJCO',
#  'DK',
#  'DKNG',
#  'DKS',
#  'DLR',
#  'DLTH',
#  'DLTR',
#  'DLX',
#  'DM',
#  'DMRC',
#  'DNLI',
#  'DNMR',
#  'DNOW',
#  'DNUT',
#  'DO',
#  'DOC',
#  'DOCN',
#  'DOCU',
#  'DOLE',
#  'DOMO',
#  'DOOR',
#  'DORM',
#  'DOUG',
#  'DOV',
#  'DOW',
#  'DPZ',
#  'DRH',
#  'DRI',
#  'DRQ',
#  'DRS',
#  'DSGN',
#  'DSGR',
#  'DSKE',
#  'DSP',
#  'DT',
#  'DTC',
#  'DTE',
#  'DUK',
#  'DUOL',
#  'DV',
#  'DVA',
#  'DVAX',
#  'DVN',
#  'DX',
#  'DXCM',
#  'DXLG',
#  'DXPE',
#  'DY',
#  'DYN',
#  'DZSI',
#  'EA',
#  'EAF',
#  'EAT',
#  'EB',
#  'EBAY',
#  'EBC',
#  'EBF',
#  'EBS',
#  'EBTC',
#  'ECL',
#  'ECPG',
#  'ECVT',
#  'ED',
#  'EDIT',
#  'EDU',
#  'EE',
#  'EEX',
#  'EFC',
#  'EFSC',
#  'EFX',
#  'EG',
#  'EGAN',
#  'EGBN',
#  'EGHT',
#  'EGLE',
#  'EGO',
#  'EGRX',
#  'EGY',
#  'EHAB',
#  'EHTH',
#  'EIG',
#  'EIX',
#  'EL',
#  'ELA',
#  'ELF',
#  'ELME',
#  'ELV',
#  'ELVN',
#  'EMBC',
#  'EME',
#  'EMN',
#  'EMR',
#  'ENFN',
#  'ENPH',
#  'ENR',
#  'ENS',
#  'ENSG',
#  'ENTA',
#  'ENV',
#  'ENVA',
#  'ENVX',
#  'EOG',
#  'EOLS',
#  'EOSE',
#  'EP',
#  'EPAC',
#  'EPAM',
#  'EPC',
#  'EPM',
#  'EPRT',
#  'EQBK',
#  'EQC',
#  'EQH',
#  'EQIX',
#  'EQR',
#  'EQT',
#  'ERAS',
#  'ERIE',
#  'ERII',
#  'ERJ',
#  'ES',
#  'ESCA',
#  'ESE',
#  'ESGR',
#  'ESMT',
#  'ESNT',
#  'ESQ',
#  'ESRT',
#  'ESS',
#  'ESSA',
#  'ESTC',
#  'ETD',
#  'ETN',
#  'ETNB',
#  'ETR',
#  'ETRN',
#  'ETSY',
#  'ETWO',
#  'EU',
#  'EUR',
#  'EVA',
#  'EVBG',
#  'EVBN',
#  'EVC',
#  'EVCM',
#  'EVER',
#  'EVEX',
#  'EVGO',
#  'EVH',
#  'EVI',
#  'EVLV',
#  'EVRG',
#  'EVRI',
#  'EVTC',
#  'EW',
#  'EWBC',
#  'EWCZ',
#  'EWTX',
#  'EXC',
#  'EXFY',
#  'EXLS',
#  'EXP',
#  'EXPD',
#  'EXPE',
#  'EXPI',
#  'EXPO',
#  'EXR',
#  'EXTR',
#  'EYE',
#  'EYEN',
#  'EYPT',
#  'F',
#  'FA',
#  'FANG',
#  'FARO',
#  'FAST',
#  'FATE',
#  'FBIN',
#  'FBIZ',
#  'FBK',
#  'FBMS',
#  'FBNC',
#  'FBP',
#  'FBRT',
#  'FC',
#  'FCBC',
#  'FCCO',
#  'FCEL',
#  'FCF',
#  'FCFS',
#  'FCNCA',
#  'FCPT',
#  'FCX',
#  'FDBC',
#  'FDMT',
#  'FDP',
#  'FDS',
#  'FDX',
#  'FE',
#  'FEAM',
#  'FELE',
#  'FENC',
#  'FERG',
#  'FET',
#  'FF',
#  'FFBC',
#  'FFIC',
#  'FFIN',
#  'FFIV',
#  'FFWM',
#  'FG',
#  'FGEN',
#  'FHTX',
#  'FI',
#  'FIBK',
#  'FICO',
#  'FIGS',
#  'FIHL',
#  'FIP',
#  'FIS',
#  'FISI',
#  'FITB',
#  'FIVN',
#  'FIX',
#  'FIZZ',
#  'FL',
#  'FLEX',
#  'FLGT',
#  'FLIC',
#  'FLL',
#  'FLNC',
#  'FLNG',
#  'FLR',
#  'FLS',
#  'FLT',
#  'FLUT',
#  'FLWS',
#  'FLYW',
#  'FMAO',
#  'FMBH',
#  'FMC',
#  'FMNB',
#  'FMX',
#  'FN',
#  'FNA',
#  'FNF',
#  'FNKO',
#  'FNLC',
#  'FOA',
#  'FOLD',
#  'FOR',
#  'FORM',
#  'FORR',
#  'FOSL',
#  'FOUR',
#  'FOX',
#  'FOXA',
#  'FOXF',
#  'FPI',
#  'FRBA',
#  'FRGE',
#  'FRME',
#  'FROG',
#  'FRPH',
#  'FRPT',
#  'FRSH',
#  'FRST',
#  'FRT',
#  'FSBC',
#  'FSBW',
#  'FSLR',
#  'FSLY',
#  'FSR',
#  'FSS',
#  'FTAI',
#  'FTCI',
#  'FTDR',
#  'FTNT',
#  'FTV',
#  'FUBO',
#  'FUL',
#  'FULT',
#  'FVCB',
#  'FWRD',
#  'FWRG',
#  'GABC',
#  'GAMB',
#  ...]

# %% [markdown]
# ## Prepare earnings and sales data

# %%
import fmpsdk

# Company Valuation Methods
symbol: str = "AAPL"
symbols: ["AAPL", "CSCO", "QQQQ"]
exchange: str = "NYSE"
exchanges: ["NYSE", "NASDAQ"]
query: str = "AA"
limit: int = 3
period: str = "quarter"
download: bool = True
market_cap_more_than: int = 1000000000
beta_more_than: int = 1
volume_more_than: int = 10000
sector: str = "Technology"
dividend_more_than: int = 0
industry: str = "Software"
filing_type: str = "10-K"
print(f"Company Profile: {fmpsdk.company_profile(apikey=FMP_API_KEY, symbol=symbol)=}")
# Out:
# Company Profile: fmpsdk.company_profile(apikey=FMP_API_KEY, symbol=symbol)=[{'symbol': 'AAPL', 'price': 186.742, 'beta': 1.29, 'volAvg': 53759957, 'mktCap': 2887386129800, 'lastDiv': 0.96, 'range': '143.9-199.62', 'changes': -0.118, 'companyName': 'Apple Inc.', 'currency': 'USD', 'cik': '0000320193', 'isin': 'US0378331005', 'cusip': '037833100', 'exchange': 'NASDAQ Global Select', 'exchangeShortName': 'NASDAQ', 'industry': 'Consumer Electronics', 'website': 'https://www.apple.com', 'description': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was incorporated in 1977 and is headquartered in Cupertino, California.', 'ceo': 'Mr. Timothy D. Cook', 'sector': 'Technology', 'country': 'US', 'fullTimeEmployees': '161000', 'phone': '408 996 1010', 'address': 'One Apple Park Way', 'city': 'Cupertino', 'state': 'CA', 'zip': '95014', 'dcfDiff': 39.38604, 'dcf': 146.41895654805498, 'image': 'https://financialmodelingprep.com/image-stock/AAPL.png', 'ipoDate': '1980-12-12', 'defaultImage': False, 'isEtf': False, 'isActivelyTrading': True, 'isAdr': False, 'isFund': False}]

# %%
earnings_all_df = pd.DataFrame()
for ticker in stocks_ticker_set: # ['AAON']: #
    earnings = fmpsdk.historical_earning_calendar(apikey=FMP_API_KEY, symbol=ticker, limit=-1)
    if earnings is not None and len(earnings) > 0:
        edf = pd.DataFrame(earnings)
        edf['date'] = pd.to_datetime(edf['date'])
        edf = edf.set_index(['symbol', 'date'])
        # edf = edf.pivot(columns='symbol')
        # edf.swaplevel(i=0,j=1, axis=0)
        # edf.drop(columns=['symbol'])
        earnings_all_df = pd.concat([earnings_all_df, edf])
        n_earnings = len(earnings)
        # print(f"Total earnings reports for {ticker}: {n_earnings}")
#    earliest_earn = earnings[-1] if len(earnings > 0 else 'None')
#    print(f"Earliest earnings report for {ticker}: {earliest_earn}")
# Out:
# ERROR:root:A requests exception has occurred that we have not yet detailed an 'except' clause for.  Error: Expecting value: line 1 column 1 (char 0)
# ERROR:root:Connection to https://financialmodelingprep.com/api/v3/historical/earning_calendar/MMI failed:  DNS failure, refused connection or some other connection related issue.
# ERROR:root:Connection to https://financialmodelingprep.com/api/v3/historical/earning_calendar/GEFB timed out.
# ERROR:root:Connection to https://financialmodelingprep.com/api/v3/historical/earning_calendar/BKR failed:  DNS failure, refused connection or some other connection related issue.
# ERROR:root:Connection to https://financialmodelingprep.com/api/v3/historical/earning_calendar/BHRB failed:  DNS failure, refused connection or some other connection related issue.
# ERROR:root:Connection to https://financialmodelingprep.com/api/v3/historical/earning_calendar/CYBR failed:  DNS failure, refused connection or some other connection related issue.

# %%
earnings
# Out:
# [{'date': '2024-02-27',
#   'symbol': 'FLYW',
#   'eps': None,
#   'epsEstimated': -0.08,
#   'time': 'amc',
#   'revenue': None,
#   'revenueEstimated': 89960000,
#   'updatedFromDate': '2024-02-02',
#   'fiscalDateEnding': '2023-12-30'},
#  {'date': '2023-11-07',
#   'symbol': 'FLYW',
#   'eps': 0.08,
#   'epsEstimated': 0.1,
#   'time': 'amc',
#   'revenue': 123323000,
#   'revenueEstimated': 90520000,
#   'updatedFromDate': '2024-02-02',
#   'fiscalDateEnding': '2023-09-30'},
#  {'date': '2023-08-08',
#   'symbol': 'FLYW',
#   'eps': -0.15,
#   'epsEstimated': -0.15,
#   'time': 'amc',
#   'revenue': 84869000,
#   'revenueEstimated': 74950000,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2023-06-30'},
#  {'date': '2023-05-09',
#   'symbol': 'FLYW',
#   'eps': -0.03,
#   'epsEstimated': -0.05,
#   'time': 'amc',
#   'revenue': 94357000,
#   'revenueEstimated': 83870000,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2023-03-31'},
#  {'date': '2023-02-28',
#   'symbol': 'FLYW',
#   'eps': -0.01,
#   'epsEstimated': -0.11,
#   'time': 'amc',
#   'revenue': 73053000,
#   'revenueEstimated': 84390000,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2022-12-31'},
#  {'date': '2022-11-08',
#   'symbol': 'FLYW',
#   'eps': -0.04,
#   'epsEstimated': 0.06,
#   'time': 'amc',
#   'revenue': 95232000,
#   'revenueEstimated': None,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2022-09-30'},
#  {'date': '2022-08-09',
#   'symbol': 'FLYW',
#   'eps': -0.22,
#   'epsEstimated': -0.17,
#   'time': 'amc',
#   'revenue': 56537000,
#   'revenueEstimated': None,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2022-06-30'},
#  {'date': '2022-05-10',
#   'symbol': 'FLYW',
#   'eps': -0.1,
#   'epsEstimated': -0.03278,
#   'time': 'amc',
#   'revenue': 64553000,
#   'revenueEstimated': 41440000,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2022-03-31'},
#  {'date': '2022-03-02',
#   'symbol': 'FLYW',
#   'eps': -0.11,
#   'epsEstimated': -0.08,
#   'time': 'amc',
#   'revenue': 51394000,
#   'revenueEstimated': 57580000,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2021-12-31'},
#  {'date': '2021-11-09',
#   'symbol': 'FLYW',
#   'eps': 0.08,
#   'epsEstimated': 0.00364,
#   'time': 'amc',
#   'revenue': 67788000,
#   'revenueEstimated': 51500000,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2021-09-30'},
#  {'date': '2021-08-10',
#   'symbol': 'FLYW',
#   'eps': -0.16,
#   'epsEstimated': -0.18,
#   'time': 'amc',
#   'revenue': 36976000,
#   'revenueEstimated': 25830000,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2021-06-30'},
#  {'date': '2021-06-01',
#   'symbol': 'FLYW',
#   'eps': -0.08669,
#   'epsEstimated': None,
#   'time': 'bmo',
#   'revenue': 44991000,
#   'revenueEstimated': None,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2021-03-31'},
#  {'date': '2020-12-31',
#   'symbol': 'FLYW',
#   'eps': -0.04523,
#   'epsEstimated': None,
#   'time': 'amc',
#   'revenue': 33231000,
#   'revenueEstimated': None,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2020-12-31'},
#  {'date': '2020-09-30',
#   'symbol': 'FLYW',
#   'eps': 0.05858,
#   'epsEstimated': None,
#   'time': 'amc',
#   'revenue': 42086000,
#   'revenueEstimated': None,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2020-09-30'},
#  {'date': '2020-06-30',
#   'symbol': 'FLYW',
#   'eps': -0.1795,
#   'epsEstimated': None,
#   'time': 'amc',
#   'revenue': 23757000,
#   'revenueEstimated': None,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2020-06-30'},
#  {'date': '2020-03-31',
#   'symbol': 'FLYW',
#   'eps': 0.04152,
#   'epsEstimated': None,
#   'time': 'amc',
#   'revenue': 32709000,
#   'revenueEstimated': None,
#   'updatedFromDate': '2023-12-04',
#   'fiscalDateEnding': '2020-03-31'}]

# %%
aaon = earnings_all_df.loc[['AAON']]

# %%
aaon
# Out:
#                        eps  epsEstimated time      revenue  revenueEstimated  \
# symbol date
# AAON   2024-11-04      NaN           NaN  amc          NaN               NaN
#        2024-08-01      NaN           NaN  amc          NaN               NaN
#        2024-05-02      NaN           NaN  amc          NaN               NaN
#        2024-02-26      NaN          0.53  bmo          NaN       294360000.0
#        2023-11-06  0.64000          0.55  amc  311970000.0       294360000.0
# ...                    ...           ...  ...          ...               ...
#        1991-03-31 -0.00159           NaN  bmo    5700000.0               NaN
#        1990-12-31  0.00352           NaN  bmo   36100000.0               NaN
#        1990-09-30  0.00703           NaN  bmo   10100000.0               NaN
#        1990-06-30  0.00703           NaN  bmo    9300000.0               NaN
#        1990-03-31  0.00352           NaN  bmo    8200000.0               NaN
#
#                   updatedFromDate fiscalDateEnding
# symbol date
# AAON   2024-11-04      2024-02-02       2024-09-30
#        2024-08-01      2024-02-02       2024-06-30
#        2024-05-02      2024-02-02       2024-03-30
#        2024-02-26      2024-02-02       2023-12-30
#        2023-11-06      2024-02-02       2023-09-30
# ...                           ...              ...
#        1991-03-31      2023-12-04       1991-03-31
#        1990-12-31      2023-12-04       1990-12-31
#        1990-09-30      2023-12-04       1990-09-30
#        1990-06-30      2023-12-04       1990-06-30
#        1990-03-31      2023-12-04       1990-03-31
#
# [138 rows x 7 columns]

# %%
len(earnings_all_df)
# Out:
# 216678

# %%
earnings_all_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 earnings_all_df
#
# NameError: name 'earnings_all_df' is not defined

# %%
len(earnings_all_df.index.levels[0])
# Out:
# 2641

# %%
# earnings_file = 'data/earnings_calendar.csv.bz2'
earnings_file = 'data/data-3rd-party/earnings_calendar.parquet'

# %%
# earnings_all_df.to_csv(earnings_file)
earnings_all_df.to_parquet(earnings_file)

# %% [markdown]
# ### Read back data and verify it

# %%
import pandas as pd

tmp_earn_df = pd.read_parquet(earnings_file)
tmp_earn_df

# earnings_loaded_df = pd.read_csv('data/earnings_calendar.csv.bz2', index_col=['symbol', 'date'])
# print(earnings_loaded_df)
# Out:
#                       eps  epsEstimated time       revenue  revenueEstimated  \
# symbol date
# A      1999-01-31  0.1600           NaN  amc  1.786000e+09               NaN
#        1999-04-30  0.3400           NaN  amc  2.010000e+09               NaN
#        1999-07-31  0.3000           NaN  amc  2.087000e+09               NaN
#        1999-10-31  0.3318           NaN  amc  2.448000e+09               NaN
#        2000-02-17  0.3000          0.22  bmo  2.246000e+09      1.357400e+09
# ...                   ...           ...  ...           ...               ...
# ZYXI   2023-10-26  0.1000          0.09  bmo  4.991500e+07      5.453000e+07
#        2024-03-04     NaN          0.17  bmo           NaN      5.453000e+07
#        2024-04-25     NaN           NaN  bmo           NaN               NaN
#        2024-07-25     NaN           NaN  bmo           NaN               NaN
#        2024-10-24     NaN           NaN  bmo           NaN               NaN
#
#                   updatedFromDate fiscalDateEnding
# symbol date
# A      1999-01-31      2023-12-04       1999-01-31
#        1999-04-30      2023-12-04       1999-04-30
#        1999-07-31      2023-12-04       1999-07-31
#        1999-10-31      2023-12-04       1999-10-31
#        2000-02-17      2023-12-04       2000-01-31
# ...                           ...              ...
# ZYXI   2023-10-26      2024-01-26       2023-09-30
#        2024-03-04      2024-02-02       2023-12-30
#        2024-04-25      2024-02-02       2024-03-30
#        2024-07-25      2024-02-02       2024-06-30
#        2024-10-24      2024-02-02       2024-09-30
#
# [216678 rows x 7 columns]

# %%
tmp_earn_df.index.names = ['Symbol', 'Date']

# %% [markdown]
# ## Prepare historical dividends
#   * This is secondary information since growth stocks usually do not have dividends and rarely have splits
#   * Additionally the dividends and split information is partially reflected in Adj Close of price history data

# %%
def fetch_dividends_history():
    divs_hist_all_df = pd.DataFrame()
    for ticker in stocks_ticker_set: # ['AAON']:
        divs_hist = fmpsdk.historical_stock_dividend(apikey=FMP_API_KEY, symbol=ticker)
        # print(f"Loaded historical dividends for {ticker}: \n{divs_hist}")
        print(f"Loaded {len(divs_hist['historical'])} historical dividends for {ticker}")
        if divs_hist['historical'] is not None and len(divs_hist['historical']) > 0:
            dh_df_tmp = pd.DataFrame.from_dict(data=divs_hist['historical'])
            # print(f"Historical dividends for {ticker} dataframe: \n{dh_df_tmp.head()}")
            dh_df_tmp['symbol'] = ticker
            dh_df = dh_df_tmp
            # print(f"Historical dividends for {ticker} dataframe: \n{dh_df_tmp.head()}")
            # print(f"Historical dividends for {ticker} full dataframe: \n{dh_df.head()}")
            dh_df['date'] = pd.to_datetime(dh_df['date'])
            dh_df = dh_df.set_index(['symbol', 'date'])
            n_divs_hist = len(dh_df)
            print(f"Total dividends history reports for {ticker}: {n_divs_hist}")
            # print(f"Historical dividends for {ticker} full dataframe: \n{dh_df}")
            divs_hist_all_df = pd.concat([divs_hist_all_df, dh_df])
    return divs_hist_all_df

# %%
# divs_hist_file = 'data/dividends_history.csv.bz2'

# %%
# divs_hist_all_df.to_csv(divs_hist_file)

# %% [markdown]
# ## Prepare key metrics data for company fundamentals

# %%
keymetrics_all_df = pd.DataFrame()
for ticker in stocks_ticker_set:
    kms = fmpsdk.key_metrics(apikey=FMP_API_KEY, symbol=ticker, period='quarter', limit=-1)
    if kms is not None and len(kms) > 0:
        kms_df = pd.DataFrame(kms)
        kms_df['date'] = pd.to_datetime(kms_df['date'])
        kms_df = kms_df.set_index(['symbol', 'date'])
        # print(f"Key metrics for {ticker} sample: \n{kms_df.columns}")
        keymetrics_all_df = pd.concat([keymetrics_all_df, kms_df])
        # print(f"Key metrics concatenated {ticker}: \n{keymetrics_all_df.columns}")
        n_kms = len(kms_df)
        print(f"Total key metrics reports for {ticker}: {n_kms}")
    else:
        print(f"No {ticker} key metrics reports: kms={kms}")
# Out:
# Total key metrics reports for IAUX: 15
# Total key metrics reports for PGEN: 48
# Total key metrics reports for PETQ: 31
# Total key metrics reports for NUVB: 15
# Total key metrics reports for HSY: 153
# No ESH4 key metrics reports: kms=[]
# Total key metrics reports for ALVR: 19
# Total key metrics reports for VTS: 6
# Total key metrics reports for ME: 14
# Total key metrics reports for SUM: 40
# Total key metrics reports for LAW: 15
# Total key metrics reports for EQT: 153
# Total key metrics reports for INN: 59
# Total key metrics reports for BURL: 47
# Total key metrics reports for ODC: 153
# Total key metrics reports for OPEN: 15
# Total key metrics reports for KHC: 51
# Total key metrics reports for GCMG: 15
# Total key metrics reports for FPI: 43
# Total key metrics reports for O: 117
# Total key metrics reports for SFIX: 29
# Total key metrics reports for UE: 43
# Total key metrics reports for NVEC: 115
# Total key metrics reports for AWR: 153
# Total key metrics reports for MNDY: 15
# Total key metrics reports for PARA: 128
# Total key metrics reports for GNK: 75
# Total key metrics reports for SPLK: 52
# Total key metrics reports for LXFR: 52
# Total key metrics reports for VECO: 123
# Total key metrics reports for MNSB: 59
# Total key metrics reports for CCOI: 88
# Total key metrics reports for VYGR: 37
# Total key metrics reports for TIPT: 66
# Total key metrics reports for DTE: 153
# Total key metrics reports for AEIS: 111
# Total key metrics reports for ITOS: 19
# Total key metrics reports for SPOT: 31
# Total key metrics reports for AMP: 76
# Total key metrics reports for EW: 96
# Total key metrics reports for XHR: 39
# Total key metrics reports for ENV: 59
# Total key metrics reports for KMT: 153
# Total key metrics reports for LFST: 15
# Total key metrics reports for WLLBW: 83
# Total key metrics reports for THFF: 131
# Total key metrics reports for SDRL: 45
# Total key metrics reports for CASH: 125
# Total key metrics reports for ATLC: 99
# Total key metrics reports for CEG: 12
# Total key metrics reports for STKS: 67
# Total key metrics reports for MGNX: 45
# Total key metrics reports for MWA: 75
# Total key metrics reports for SMMT: 64
# Total key metrics reports for NWE: 153
# Total key metrics reports for IBEX: 22
# Total key metrics reports for FLGT: 34
# Total key metrics reports for EMBC: 14
# Total key metrics reports for FBIN: 55
# Total key metrics reports for RMBS: 112
# Total key metrics reports for CDAY: 27
# Total key metrics reports for MGEE: 153
# ERROR:root:A requests exception has occurred that we have not yet detailed an 'except' clause for.  Error: Expecting value: line 1 column 1 (char 0)
# Total key metrics reports for CCRN: 91
# No The content contained herein is owned or licensed by BlackRock and/or its third-party information providers and is protected by applicable copyrights, trademarks, service marks, and/or other intellectual property rights. Such content is solely for your personal, non-commercial use. Accordingly, you may not copy, distribute, modify, post, frame or deep link this content. You may download material displayed on this Website for your personal use provided you also retain all copyright and other proprietary notices contained on the materials. Modification or use of the materials for any other purpose violates BlackRock's intellectual property rights.
# Holdings subject to change. See www.iShares.com for the most recent funds holdings.
# The values for “price” shown herein generally represent a price provided by a third-party pricing vendor for the portfolio holding and do not reflect the impact of systematic fair valuation (“the vendor price”). The vendor price is not necessarily the price at which the Fund values the portfolio holding for the purposes of determining its net asset value (the “valuation price”). Additionally, where applicable, foreign currency exchange rates with respect to the portfolio holdings denominated in non-U.S. currencies for the valuation price will be generally determined as of the close of business on the New York Stock Exchange, whereas for the vendor price will be generally determined as of 4 p.m. London. The values shown herein for “market value,” “weight,” and “notional value” (the “calculated values”) are based off of the vendor price and may have been different if the valuation price were to have been used to calculate such values. The vendor price is as of the most recent practicable date and may not necessarily be as of the date shown above.
# Please see the “Determination of Net Asset Value” section of each Fund’s prospectus for additional information on the Fund’s valuation policies and procedures.
# CAREFULLY CONSIDER THE FUNDS' INVESTMENT OBJECTIVES, RISK FACTORS, AND CHARGES AND EXPENSES BEFORE INVESTING. THIS AND OTHER INFORMATION CAN BE FOUND IN THE FUNDS' PROSPECTUSES OR, IF AVAILABLE, THE SUMMARY PROSPECTUSES WHICH MAY BE OBTAINED BY VISITING WWW.ISHARES.COM OR WWW.BLACKROCK.COM. READ THE PROSPECTUS CAREFULLY BEFORE INVESTING. INVESTING INVOLVES RISK, INCLUDING POSSIBLE LOSS OF PRINCIPAL.
# This information should not be relied upon as research, investment advice, or a recommendation regarding any products, strategies, or any security in particular.
# This material is strictly for illustrative, educational, or informational purposes and is subject to change.
# The Funds are distributed by BlackRock Investments, LLC (together with its affiliates, “BlackRock”).
# The iShares Funds are not sponsored, endorsed, issued, sold or promoted by Bloomberg, BlackRock Index Services, LLC, Cboe Global Indices, LLC, Cohen & Steers, European Public Real Estate Association (“EPRA® ”), FTSE International Limited (“FTSE”), ICE Data Indices, LLC, NSE Indices Ltd, JPMorgan, JPX Group, London Stock Exchange Group (“LSEG”), MSCI Inc., Markit Indices Limited, Morningstar, Inc., Nasdaq, Inc., National Association of Real Estate Investment Trusts (“NAREIT”), Nikkei, Inc., Russell, S&P Dow Jones Indices LLC or STOXX Ltd. None of these companies make any representation regarding the advisability of investing in the Funds. With the exception of BlackRock Index Services, LLC, who is an affiliate, BlackRock Investments, LLC is not affiliated with the companies listed above. Neither FTSE, LSEG, nor NAREIT makes any warranty regarding the FTSE Nareit Equity REITS Index, FTSE Nareit All Residential Capped Index or FTSE Nareit All Mortgage Capped Index. Neither FTSE, EPRA, LSEG, nor NAREIT makes any warranty regarding the FTSE EPRA Nareit Developed ex-U.S. Index, FTSE EPRA Nareit Developed Green Target Index or FTSE EPRA Nareit Global REITs Index. “FTSE®” is a trademark of London Stock Exchange Group companies and is used by FTSE under license.
# ©2023 BlackRock, Inc or its affiliates. All rights reserved. iSHARES, iBONDS and BLACKROCK are trademarks of BlackRock, Inc. or its affiliates. All other trademarks are those of their respective owners.
# iCRMH0323U/S-2742939 key metrics reports: kms=None
# Total key metrics reports for MOH: 83
# Total key metrics reports for NREF: 26
# Total key metrics reports for DAN: 153
# Total key metrics reports for MGTX: 27
# Total key metrics reports for ADTN: 123
# Total key metrics reports for TGNA: 153
# Total key metrics reports for ALNT: 152
# Total key metrics reports for AMPL: 13
# Total key metrics reports for BXC: 77
# Total key metrics reports for CBRL: 153
# Total key metrics reports for RUSHA: 115
# Total key metrics reports for ATNM: 69
# Total key metrics reports for CNOB: 115
# Total key metrics reports for KRYS: 29
# Total key metrics reports for SLRN: 7
# Total key metrics reports for ZD: 99
# Total key metrics reports for FRSH: 33
# Total key metrics reports for FLR: 93
# Total key metrics reports for IQV: 48
# Total key metrics reports for ASC: 47
# Total key metrics reports for SLDP: 12
# Total key metrics reports for CRWD: 23
# Total key metrics reports for FROG: 21
# Total key metrics reports for ETNB: 21
# Total key metrics reports for MODV: 87
# Total key metrics reports for AER: 75
# Total key metrics reports for WMB: 153
# Total key metrics reports for XFOR: 28
# Total key metrics reports for EE: 117
# Total key metrics reports for PEG: 153
# Total key metrics reports for ABVX: 18
# Total key metrics reports for CVCO: 86
# Total key metrics reports for NVTA: 40
# Total key metrics reports for AX: 77
# Total key metrics reports for EBS: 84
# Total key metrics reports for BROS: 13
# Total key metrics reports for NXT: 8
# Total key metrics reports for UONE: 99
# Total key metrics reports for LCNB: 97
# Total key metrics reports for CDE: 153
# Total key metrics reports for VRDN: 43
# Total key metrics reports for RCUS: 27
# Total key metrics reports for PJT: 39
# Total key metrics reports for ABT: 154
# Total key metrics reports for PCOR: 19
# Total key metrics reports for VLGEA: 153
# No MOGA key metrics reports: kms=[]
# Total key metrics reports for OCUL: 43
# Total key metrics reports for NIC: 47
# Total key metrics reports for GRC: 153
# Total key metrics reports for PEP: 153
# Total key metrics reports for TMST: 43
# Total key metrics reports for OMER: 61
# Total key metrics reports for IESC: 104
# Total key metrics reports for BRO: 154
# Total key metrics reports for NABL: 15
# Total key metrics reports for BIIB: 153
# Total key metrics reports for ILMN: 95
# Total key metrics reports for PLAB: 153
# Total key metrics reports for RELX: 49
# Total key metrics reports for CSTR: 33
# Total key metrics reports for CDNS: 151
# Total key metrics reports for INZY: 19
# Total key metrics reports for FISI: 100
# Total key metrics reports for CTRE: 45
# Total key metrics reports for ARQT: 20
# Total key metrics reports for AXNX: 27
# Total key metrics reports for OC: 143
# Total key metrics reports for GLUE: 15
# Total key metrics reports for SYK: 153
# Total key metrics reports for WSBC: 139
# Total key metrics reports for AGYS: 154
# Total key metrics reports for RPAY: 24
# Total key metrics reports for ACA: 25
# Total key metrics reports for PDLI: 97
# Total key metrics reports for FICO: 153
# Total key metrics reports for OMI: 153
# No USD key metrics reports: kms=[]
# Total key metrics reports for CASS: 115
# Total key metrics reports for BWFG: 58
# Total key metrics reports for SSTK: 51
# Total key metrics reports for TNET: 43
# Total key metrics reports for TRI: 111
# Total key metrics reports for MEG: 20
# Total key metrics reports for LDOS: 73
# Total key metrics reports for EVGO: 14
# Total key metrics reports for TGH: 75
# Total key metrics reports for APPS: 83
# Total key metrics reports for NWPX: 119
# Total key metrics reports for ZUMZ: 83
# Total key metrics reports for IMGN: 141
# Total key metrics reports for FCCO: 110
# Total key metrics reports for PEBO: 131
# Total key metrics reports for F: 153
# Total key metrics reports for BOC: 45
# Total key metrics reports for DOOR: 47
# Total key metrics reports for ZTS: 51
# Total key metrics reports for KD: 14
# Total key metrics reports for EXPD: 153
# Total key metrics reports for REVG: 34
# Total key metrics reports for TSLA: 64
# Total key metrics reports for PNFP: 93
# Total key metrics reports for IMAX: 119
# Total key metrics reports for TGI: 118
# Total key metrics reports for URI: 105
# Total key metrics reports for FSLY: 23
# Total key metrics reports for HTBI: 53
# Total key metrics reports for DV: 15
# Total key metrics reports for CATC: 74
# Total key metrics reports for GKOS: 39
# Total key metrics reports for CCSI: 13
# Total key metrics reports for HVT: 153
# Total key metrics reports for AZZ: 154
# Total key metrics reports for NOVA: 23
# Total key metrics reports for HOLX: 140
# Total key metrics reports for PPTA: 54
# Total key metrics reports for HCI: 67
# Total key metrics reports for WPM: 99
# Total key metrics reports for RRBI: 24
# Total key metrics reports for TPR: 93
# Total key metrics reports for NOC: 154
# Total key metrics reports for PPBI: 108
# Total key metrics reports for HRMY: 19
# Total key metrics reports for UTMD: 147
# Total key metrics reports for LVS: 79
# Total key metrics reports for NRDY: 14
# Total key metrics reports for ENPH: 55
# Total key metrics reports for KFRC: 119
# Total key metrics reports for CNSL: 78
# Total key metrics reports for STOK: 23
# Total key metrics reports for BKKT: 13
# Total key metrics reports for LII: 100
# Total key metrics reports for BANR: 111
# Total key metrics reports for MAR: 103
# Total key metrics reports for LUMN: 151
# Total key metrics reports for WW: 97
# Total key metrics reports for TWKS: 14
# Total key metrics reports for CRMT: 142
# Total key metrics reports for RAPT: 23
# Total key metrics reports for MAXN: 19
# Total key metrics reports for WIX: 45
# Total key metrics reports for BYND: 25
# Total key metrics reports for CBAN: 112
# Total key metrics reports for GNRC: 61
# Total key metrics reports for WASH: 143
# Total key metrics reports for YORW: 111
# Total key metrics reports for SILK: 23
# Total key metrics reports for USPH: 131
# Total key metrics reports for SPGI: 153
# Total key metrics reports for INFN: 74
# Total key metrics reports for NKLA: 22
# Total key metrics reports for SIGI: 153
# Total key metrics reports for BTBT: 23
# Total key metrics reports for CL: 153
# Total key metrics reports for ATEC: 80
# Total key metrics reports for TALO: 26
# Total key metrics reports for CCL: 94
# Total key metrics reports for MAC: 119
# Total key metrics reports for CZR: 135
# Total key metrics reports for MATX: 153
# Total key metrics reports for AMBC: 131
# Total key metrics reports for IBM: 154
# Total key metrics reports for TMHC: 48
# Total key metrics reports for KRG: 82
# Total key metrics reports for AXGN: 148
# Total key metrics reports for AMK: 23
# Total key metrics reports for VCEL: 108
# Total key metrics reports for DTC: 14
# Total key metrics reports for BRCC: 12
# Total key metrics reports for PCVX: 19
# Total key metrics reports for RPD: 39
# Total key metrics reports for GLDD: 79
# Total key metrics reports for HWC: 137
# Total key metrics reports for CMS: 153
# Total key metrics reports for BAND: 31
# Total key metrics reports for LYV: 75
# Total key metrics reports for BIRK: 5
# Total key metrics reports for PCH: 154
# Total key metrics reports for EBAY: 103
# Total key metrics reports for CATY: 134
# Total key metrics reports for MYFW: 27
# Total key metrics reports for DHC: 99
# Total key metrics reports for DNUT: 15
# Total key metrics reports for BDN: 152
# Total key metrics reports for NWSA: 49
# Total key metrics reports for DKNG: 19
# Total key metrics reports for PRME: 11
# Total key metrics reports for SIRI: 120
# Total key metrics reports for NWLI: 153
# Total key metrics reports for JACK: 132
# Total key metrics reports for SYF: 43
# ERROR:root:Connection to https://financialmodelingprep.com/api/v3/key-metrics/AMNB failed:  DNS failure, refused connection or some other connection related issue.
# Total key metrics reports for DIN: 135
# No AMNB key metrics reports: kms=None
# Total key metrics reports for ROVR: 14
# Total key metrics reports for ALLE: 44
# Total key metrics reports for KO: 153
# Total key metrics reports for INTU: 124
# Total key metrics reports for BE: 27
# Total key metrics reports for ABBNY: 91
# Total key metrics reports for GCT: 11
# Total key metrics reports for RCKY: 132
# Total key metrics reports for MBIN: 31
# Total key metrics reports for UTZ: 21
# Total key metrics reports for RGCO: 120
# Total key metrics reports for MO: 153
# Total key metrics reports for EXTR: 102
# Total key metrics reports for ONTF: 17
# Total key metrics reports for CPS: 75
# Total key metrics reports for NATH: 126
# Total key metrics reports for ACMR: 32
# Total key metrics reports for CIFR: 14
# Total key metrics reports for UBER: 24
# Total key metrics reports for IOT: 12
# Total key metrics reports for TGT: 153
# Total key metrics reports for SMLR: 47
# Total key metrics reports for MXL: 61
# Total key metrics reports for AAT: 57
# Total key metrics reports for PSTL: 23
# Total key metrics reports for DSP: 16
# Total key metrics reports for COMP: 14
# Total key metrics reports for LNT: 153
# Total key metrics reports for PLD: 103
# Total key metrics reports for GBX: 119
# Total key metrics reports for SN: 6
# Total key metrics reports for QSI: 14
# Total key metrics reports for BL: 36
# Total key metrics reports for PLBC: 88
# Total key metrics reports for III: 68
# Total key metrics reports for TMUS: 76
# Total key metrics reports for UIS: 153
# Total key metrics reports for KROS: 19
# Total key metrics reports for SEM: 71
# Total key metrics reports for DMRC: 67
# Total key metrics reports for INGN: 44
# Total key metrics reports for DCPH: 29
# Total key metrics reports for CAT: 153
# Total key metrics reports for TRGP: 57
# Total key metrics reports for GTLB: 13
# Total key metrics reports for TNK: 66
# Total key metrics reports for OCFC: 111
# Total key metrics reports for SCHL: 138
# Total key metrics reports for BIG: 151
# Total key metrics reports for LVWR: 11
# Total key metrics reports for EPRT: 27
# Total key metrics reports for OVID: 31
# Total key metrics reports for STNG: 60
# Total key metrics reports for RC: 47
# Total key metrics reports for FGEN: 41
# Total key metrics reports for SBGI: 119
# Total key metrics reports for CRSR: 17
# Total key metrics reports for MRO: 135
# Total key metrics reports for GDEN: 100
# Total key metrics reports for MRSN: 31
# Total key metrics reports for COUR: 15
# Total key metrics reports for CSGP: 103
# No URNM key metrics reports: kms=[]
# Total key metrics reports for WINA: 121
# Total key metrics reports for BTAI: 27
# Total key metrics reports for CECO: 135
# Total key metrics reports for EAF: 119
# Total key metrics reports for EVER: 27
# Total key metrics reports for OBK: 27
# Total key metrics reports for GAMB: 15
# Total key metrics reports for MCFT: 39
# No METCV key metrics reports: kms=[]
# Total key metrics reports for WTBA: 87
# Total key metrics reports for CNK: 75
# Total key metrics reports for BWB: 28
# Total key metrics reports for WK: 42
# Total key metrics reports for SPNT: 47
# Total key metrics reports for AEVA: 17
# Total key metrics reports for ASAN: 19
# Total key metrics reports for OZK: 107
# Total key metrics reports for MPWR: 87
# Total key metrics reports for ADSK: 153
# Total key metrics reports for ALGN: 93
# Total key metrics reports for ACT: 15
# Total key metrics reports for TMP: 140
# Total key metrics reports for WBD: 79
# Total key metrics reports for MYGN: 113
# Total key metrics reports for LADR: 47
# Total key metrics reports for BANF: 127
# Total key metrics reports for RL: 106
# Total key metrics reports for IRTC: 33
# Total key metrics reports for TRMB: 143
# Total key metrics reports for MACK: 55
# Total key metrics reports for PANW: 51
# Total key metrics reports for KRNY: 81
# Total key metrics reports for SWK: 153
# Total key metrics reports for NU: 13
# Total key metrics reports for AMPY: 52
# Total key metrics reports for MNST: 136
# Total key metrics reports for FNLC: 115
# Total key metrics reports for SKIN: 15
# Total key metrics reports for KZR: 27
# Total key metrics reports for APTV: 56
# Total key metrics reports for GWRS: 36
# Total key metrics reports for AMTB: 27
# Total key metrics reports for CARM: 44
# Total key metrics reports for AMWL: 17
# Total key metrics reports for SST: 14
# Total key metrics reports for ANIK: 122
# Total key metrics reports for AUB: 110
# Total key metrics reports for PTEN: 127
# Total key metrics reports for COST: 154
# Total key metrics reports for MVIS: 109
# Total key metrics reports for OTEX: 112
# Total key metrics reports for CNM: 15
# Total key metrics reports for RGP: 94
# Total key metrics reports for OI: 131
# Total key metrics reports for SABR: 45
# Total key metrics reports for SR: 154
# Total key metrics reports for SHAK: 40
# Total key metrics reports for ZETA: 15
# Total key metrics reports for MRTN: 151
# Total key metrics reports for GTY: 152
# Total key metrics reports for FCX: 147
# Total key metrics reports for WRBY: 13
# Total key metrics reports for MTD: 106
# Total key metrics reports for TYRA: 13
# Total key metrics reports for PMT: 57
# Total key metrics reports for CLFD: 142
# Total key metrics reports for RXT: 19
# Total key metrics reports for STGW: 118
# Total key metrics reports for VRNT: 80
# Total key metrics reports for DORM: 139
# Total key metrics reports for MS: 153
# Total key metrics reports for ATEX: 40
# Total key metrics reports for ESQ: 36
# Total key metrics reports for GRMN: 95
# Total key metrics reports for RBOT: 14
# Total key metrics reports for CANO: 14
# Total key metrics reports for FHTX: 19
# Total key metrics reports for PRTA: 47
# Total key metrics reports for BFAM: 80
# Total key metrics reports for EQBK: 39
# Total key metrics reports for CHEF: 55
# Total key metrics reports for LAZR: 20
# Total key metrics reports for UTI: 83
# Total key metrics reports for CVLY: 114
# Total key metrics reports for HUBB: 154
# Total key metrics reports for FOXA: 25
# Total key metrics reports for KURA: 63
# No STHO key metrics reports: kms=[]
# Total key metrics reports for MCS: 153
# Total key metrics reports for HCC: 31
# Total key metrics reports for OPFI: 15
# Total key metrics reports for CPK: 153
# Total key metrics reports for OSG: 153
# Total key metrics reports for MHK: 131
# Total key metrics reports for ONTO: 114
# Total key metrics reports for VTNR: 110
# Total key metrics reports for PAYX: 154
# Total key metrics reports for PARR: 124
# No BITO key metrics reports: kms=[]
# Total key metrics reports for LOCO: 43
# Total key metrics reports for PGRE: 41
# Total key metrics reports for CGEM: 16
# Total key metrics reports for ESTC: 26
# Total key metrics reports for BAX: 153
# Total key metrics reports for ALLY: 87
# Total key metrics reports for ABNB: 16
# Total key metrics reports for BSIG: 41
# Total key metrics reports for VFC: 153
# Total key metrics reports for IMXI: 28
# Total key metrics reports for UNP: 154
# Total key metrics reports for ICHR: 32
# Total key metrics reports for ADI: 153
# Total key metrics reports for GPRE: 78
# Total key metrics reports for DOMO: 27
# Total key metrics reports for TSP: 15
# Total key metrics reports for SAH: 107
# Total key metrics reports for PLXS: 153
# Total key metrics reports for ACLS: 95
# Total key metrics reports for BLK: 99
# Total key metrics reports for STC: 153
# Total key metrics reports for YMAB: 25
# Total key metrics reports for SHEN: 121
# Total key metrics reports for ZWS: 114
# Total key metrics reports for DRH: 75
# Total key metrics reports for PATH: 15
# Total key metrics reports for COCO: 13
# Total key metrics reports for CFFN: 100
# Total key metrics reports for SITC: 123
# Total key metrics reports for SCWO: 106
# Total key metrics reports for MBWM: 104
# Total key metrics reports for MCD: 153
# Total key metrics reports for FRME: 147
# Total key metrics reports for ACIW: 120
# Total key metrics reports for INTT: 107
# Total key metrics reports for PAGS: 28
# Total key metrics reports for GWRE: 58
# Total key metrics reports for OPCH: 111
# Total key metrics reports for AIR: 154
# Total key metrics reports for TRTX: 29
# Total key metrics reports for IIPR: 30
# Total key metrics reports for WRK: 128
# Total key metrics reports for URBN: 121
# Total key metrics reports for NTRA: 38
# Total key metrics reports for EVRG: 153
# Total key metrics reports for AORT: 131
# Total key metrics reports for OCN: 111
# Total key metrics reports for LEN: 154
# Total key metrics reports for MSTR: 103
# Total key metrics reports for THR: 56
# Total key metrics reports for ARRY: 17
# Total key metrics reports for CLMB: 119
# Total key metrics reports for BGXX: 11
# Total key metrics reports for HLNE: 33
# Total key metrics reports for CRDO: 12
# Total key metrics reports for BLFY: 15
# Total key metrics reports for CNTY: 119
# Total key metrics reports for NTNX: 35
# Total key metrics reports for DVA: 117
# Total key metrics reports for NYT: 153
# Total key metrics reports for MOFG: 118
# Total key metrics reports for MMI: 45
# Total key metrics reports for WMT: 153
# Total key metrics reports for ALL: 127
# Total key metrics reports for HGV: 35
# Total key metrics reports for IPG: 153
# Total key metrics reports for DEI: 73
# Total key metrics reports for EYE: 29
# Total key metrics reports for CBZ: 119
# Total key metrics reports for SPOK: 81
# Total key metrics reports for FENC: 92
# Total key metrics reports for LTC: 124
# Total key metrics reports for OEC: 43
# Total key metrics reports for THRY: 40
# Total key metrics reports for ELV: 89
# Total key metrics reports for PCT: 16
# Total key metrics reports for NNOX: 21
# Total key metrics reports for PDLB: 30
# Total key metrics reports for OKTA: 32
# Total key metrics reports for GH: 25
# Total key metrics reports for DOCN: 15
# Total key metrics reports for AVA: 153
# Total key metrics reports for HRL: 153
# Total key metrics reports for RXST: 15
# Total key metrics reports for OTLK: 36
# Total key metrics reports for PINS: 23
# Total key metrics reports for ACN: 89
# Total key metrics reports for BUSE: 112
# Total key metrics reports for FCEL: 126
# Total key metrics reports for OSCR: 15
# Total key metrics reports for MEDP: 36
# Total key metrics reports for AZN: 123
# Total key metrics reports for INDI: 14
# Total key metrics reports for ASTS: 19
# Total key metrics reports for SSB: 112
# Total key metrics reports for SDGR: 22
# Total key metrics reports for FNKO: 30
# Total key metrics reports for RMR: 37
# Total key metrics reports for GDDY: 43
# Total key metrics reports for TMCI: 15
# Total key metrics reports for ALRS: 45
# Total key metrics reports for HUMA: 15
# Total key metrics reports for BOWL: 13
# Total key metrics reports for TPX: 83
# Total key metrics reports for SCL: 153
# Total key metrics reports for SBSI: 115
# Total key metrics reports for WKHS: 63
# Total key metrics reports for VICR: 143
# Total key metrics reports for DCGO: 14
# Total key metrics reports for HUBS: 41
# ERROR:root:Connection to https://financialmodelingprep.com/api/v3/key-metrics/BHVN failed:  DNS failure, refused connection or some other connection related issue.
# Total key metrics reports for OGS: 48
# No BHVN key metrics reports: kms=None
# Total key metrics reports for CPE: 119
# Total key metrics reports for DOLE: 14
# Total key metrics reports for WULF: 73
# Total key metrics reports for NX: 96
# Total key metrics reports for RCKT: 40
# Total key metrics reports for SLP: 109
# Total key metrics reports for COF: 119
# Total key metrics reports for IPI: 66
# Total key metrics reports for DHR: 154
# Total key metrics reports for PLAY: 47
# Total key metrics reports for INVH: 32
# Total key metrics reports for ALTM: 4
# Total key metrics reports for FFIC: 111
# Total key metrics reports for PRLD: 17
# Total key metrics reports for YUM: 105
# Total key metrics reports for NBIX: 111
# Total key metrics reports for EXPE: 77
# Total key metrics reports for NTAP: 112
# Total key metrics reports for SYBT: 132
# Total key metrics reports for AVNS: 43
# Total key metrics reports for NAUT: 20
# Total key metrics reports for AMBA: 51
# Total key metrics reports for AFL: 153
# Total key metrics reports for ACHR: 13
# Total key metrics reports for CWK: 28
# Total key metrics reports for NHC: 131
# Total key metrics reports for NAT: 103
# Total key metrics reports for SSP: 151
# Total key metrics reports for FANG: 56
# Total key metrics reports for KMX: 107
# Total key metrics reports for BHIL: 13
# Total key metrics reports for TCMD: 37
# Total key metrics reports for CARS: 34
# Total key metrics reports for TELL: 153
# Total key metrics reports for PNTG: 21
# Total key metrics reports for BDC: 121
# Total key metrics reports for AIT: 154
# Total key metrics reports for OII: 152
# Total key metrics reports for PCB: 42
# Total key metrics reports for MLYS: 8
# Total key metrics reports for PH: 153
# Total key metrics reports for VGR: 145
# Total key metrics reports for ORCL: 154
# Total key metrics reports for MLAB: 146
# Total key metrics reports for J: 153
# Total key metrics reports for NVRI: 153
# Total key metrics reports for VLTO: 4
# Total key metrics reports for HLLY: 14
# Total key metrics reports for CVNA: 31
# Total key metrics reports for PECO: 54
# Total key metrics reports for QLYS: 51
# Total key metrics reports for AIRS: 13
# Total key metrics reports for HYLN: 19
# Total key metrics reports for SKYW: 154
# Total key metrics reports for FOA: 14
# Total key metrics reports for JELD: 35
# Total key metrics reports for VATE: 109
# Total key metrics reports for COTY: 50
# Total key metrics reports for TMDX: 23
# Total key metrics reports for COMM: 47
# Total key metrics reports for EDU: 70
# Total key metrics reports for CNP: 153
# Total key metrics reports for BR: 71
# Total key metrics reports for EQR: 124
# Total key metrics reports for MAX: 19
# Total key metrics reports for FLS: 153
# Total key metrics reports for PI: 37
# Total key metrics reports for WKC: 152
# Total key metrics reports for STAA: 143
# No P5N994 key metrics reports: kms=[]
# Total key metrics reports for NTGR: 83
# Total key metrics reports for SMBK: 89
# Total key metrics reports for LCTX: 126
# Total key metrics reports for FIBK: 87
# Total key metrics reports for HBCP: 67
# Total key metrics reports for GSAT: 75
# Total key metrics reports for CAG: 154
# Total key metrics reports for VUZI: 61
# Total key metrics reports for CTGO: 56
# Total key metrics reports for GCBC: 101
# Total key metrics reports for HPK: 17
# Total key metrics reports for DXLG: 151
# Total key metrics reports for STBA: 135
# Total key metrics reports for FMBH: 100
# Total key metrics reports for CSCO: 145
# Total key metrics reports for VOXX: 152
# Total key metrics reports for ORLY: 123
# Total key metrics reports for CMCL: 139
# Total key metrics reports for VIGL: 13
# Total key metrics reports for WST: 153
# Total key metrics reports for LOGI: 115
# Total key metrics reports for MTB: 153
# Total key metrics reports for SITM: 20
# Total key metrics reports for CMPX: 22
# Total key metrics reports for MIR: 19
# Total key metrics reports for GSHD: 27
# Total key metrics reports for NOW: 53
# Total key metrics reports for AVTE: 15
# Total key metrics reports for ATLO: 90
# Total key metrics reports for FIVN: 43
# Total key metrics reports for BBAI: 13
# Total key metrics reports for CLDX: 152
# Total key metrics reports for HPE: 38
# Total key metrics reports for BPMC: 39
# Total key metrics reports for PHM: 153
# Total key metrics reports for ALDX: 44
# Total key metrics reports for MAS: 153
# Total key metrics reports for EVLV: 14
# Total key metrics reports for GIII: 140
# Total key metrics reports for STEP: 18
# Total key metrics reports for INMD: 23
# Total key metrics reports for KAI: 127
# Total key metrics reports for CVRX: 15
# Total key metrics reports for MXCT: 25
# Total key metrics reports for NECB: 63
# Total key metrics reports for PBF: 51
# Total key metrics reports for SANA: 16
# Total key metrics reports for FFWM: 46
# Total key metrics reports for NSIT: 116
# Total key metrics reports for TVTX: 62
# Total key metrics reports for HLMN: 17
# Total key metrics reports for ASPN: 48
# Total key metrics reports for V: 71
# Total key metrics reports for JBLU: 87
# Total key metrics reports for GBIO: 19
# Total key metrics reports for BV: 25
# Total key metrics reports for OM: 17
# Total key metrics reports for MTDR: 55
# Total key metrics reports for NUVL: 15
# Total key metrics reports for ALXO: 19
# Total key metrics reports for LAND: 49
# Total key metrics reports for GFF: 153
# Total key metrics reports for BRP: 21
# Total key metrics reports for AKRO: 23
# Total key metrics reports for BFST: 36
# Total key metrics reports for DDD: 143
# Total key metrics reports for NNI: 83
# Total key metrics reports for BTMD: 11
# Total key metrics reports for COLB: 128
# Total key metrics reports for MED: 109
# Total key metrics reports for MIRM: 20
# Total key metrics reports for SGHC: 12
# Total key metrics reports for T: 154
# Total key metrics reports for AIN: 153
# Total key metrics reports for CZNC: 115
# Total key metrics reports for BCPC: 153
# Total key metrics reports for VERI: 34
# Total key metrics reports for STRL: 111
# Total key metrics reports for RAMP: 153
# Total key metrics reports for ORGO: 31
# Total key metrics reports for BGC: 107
# Total key metrics reports for OB: 45
# Total key metrics reports for RIGL: 95
# Total key metrics reports for NEWT: 94
# Total key metrics reports for PYPL: 39
# Total key metrics reports for UCTT: 83
# Total key metrics reports for FOUR: 19
# Total key metrics reports for ADNT: 36
# Total key metrics reports for CLAR: 103
# Total key metrics reports for ARR: 65
# Total key metrics reports for DX: 138
# Total key metrics reports for LLY: 153
# Total key metrics reports for EPC: 100
# Total key metrics reports for NXPI: 59
# Total key metrics reports for SPXC: 153
# Total key metrics reports for CHRW: 111
# Total key metrics reports for OLO: 15
# Total key metrics reports for EPAC: 153
# Total key metrics reports for ESGR: 99
# Total key metrics reports for STRA: 111
# Total key metrics reports for WBS: 147
# Total key metrics reports for HOLI: 72
# Total key metrics reports for STER: 13
# Total key metrics reports for CWCO: 127
# Total key metrics reports for MMS: 108
# Total key metrics reports for SHLS: 16
# Total key metrics reports for GLNG: 84
# Total key metrics reports for HI: 68
# Total key metrics reports for SES: 63
# Total key metrics reports for ELME: 153
# Total key metrics reports for PGTI: 79
# Total key metrics reports for MOV: 127
# Total key metrics reports for MFC: 99
# Total key metrics reports for OSPN: 102
# Total key metrics reports for MTRN: 153
# Total key metrics reports for SPNS: 125
# Total key metrics reports for ZVIA: 15
# Total key metrics reports for INFU: 71
# Total key metrics reports for ZYME: 32
# Total key metrics reports for SEAS: 48
# Total key metrics reports for NODK: 33
# Total key metrics reports for TRST: 141
# Total key metrics reports for KR: 153
# Total key metrics reports for LSEA: 22
# Total key metrics reports for UNH: 153
# Total key metrics reports for FRPH: 153
# Total key metrics reports for AMAT: 153
# Total key metrics reports for STRS: 126
# Total key metrics reports for WWW: 153
# Total key metrics reports for TWI: 131
# Total key metrics reports for XP: 20
# Total key metrics reports for DLTH: 37
# Total key metrics reports for UVSP: 118
# Total key metrics reports for PDM: 87
# Total key metrics reports for DHX: 71
# Total key metrics reports for ANDE: 111
# Total key metrics reports for TTSH: 51
# Total key metrics reports for FF: 70
# Total key metrics reports for TTEC: 111
# Total key metrics reports for BRT: 153
# Total key metrics reports for PAR: 153
# Total key metrics reports for EWTX: 15
# Total key metrics reports for CLB: 113
# Total key metrics reports for GEFB: 65
# Total key metrics reports for BCAB: 16
# No BYON key metrics reports: kms=[]
# Total key metrics reports for WAFD: 154
# Total key metrics reports for IIIN: 154
# Total key metrics reports for MTSI: 53
# Total key metrics reports for THRD: 9
# Total key metrics reports for GPOR: 104
# Total key metrics reports for HNI: 153
# Total key metrics reports for AMCX: 55
# Total key metrics reports for BKNG: 99
# Total key metrics reports for UPS: 99
# Total key metrics reports for GIC: 115
# Total key metrics reports for CDNA: 43
# Total key metrics reports for BBIO: 23
# Total key metrics reports for BBSI: 123
# Total key metrics reports for STRO: 25
# Total key metrics reports for NTST: 19
# Total key metrics reports for CTS: 153
# Total key metrics reports for CARA: 44
# Total key metrics reports for COOP: 132
# Total key metrics reports for COKE: 153
# Total key metrics reports for MRC: 55
# Total key metrics reports for LWLG: 71
# Total key metrics reports for VRTS: 71
# Total key metrics reports for RY: 120
# Total key metrics reports for FWRD: 119
# Total key metrics reports for ABR: 79
# Total key metrics reports for FELE: 135
# Total key metrics reports for UEC: 75
# Total key metrics reports for NMRK: 29
# Total key metrics reports for ZNTL: 19
# Total key metrics reports for GRNT: 9
# Total key metrics reports for TSQ: 43
# Total key metrics reports for AGEN: 95
# Total key metrics reports for RYI: 60
# Total key metrics reports for SBCF: 153
# Total key metrics reports for OFIX: 131
# Total key metrics reports for ARES: 43
# Total key metrics reports for VMC: 153
# Total key metrics reports for PFE: 153
# Total key metrics reports for DOCU: 27
# Total key metrics reports for DRQ: 107
# Total key metrics reports for ONL: 14
# Total key metrics reports for CENT: 126
# Total key metrics reports for WGO: 154
# No HG key metrics reports: kms=[]
# Total key metrics reports for DCOM: 113
# Total key metrics reports for GPC: 153
# Total key metrics reports for BFLY: 15
# Total key metrics reports for MTCH: 124
# Total key metrics reports for HPP: 60
# Total key metrics reports for OBDC: 31
# Total key metrics reports for PAYS: 53
# Total key metrics reports for AVB: 119
# Total key metrics reports for L: 153
# Total key metrics reports for INCY: 121
# Total key metrics reports for DELL: 43
# Total key metrics reports for MCRI: 123
# Total key metrics reports for MLP: 115
# Total key metrics reports for ACRV: 9
# Total key metrics reports for RPHM: 16
# Total key metrics reports for ALT: 74
# Total key metrics reports for AMEH: 78
# Total key metrics reports for AEO: 124
# No ICSUAGD key metrics reports: kms=[]
# Total key metrics reports for DUOL: 15
# Total key metrics reports for BLD: 39
# Total key metrics reports for ADEA: 83
# Total key metrics reports for COOK: 15
# Total key metrics reports for AVAV: 78
# Total key metrics reports for KVUE: 8
# Total key metrics reports for HUBG: 112
# Total key metrics reports for NRIX: 17
# Total key metrics reports for DLR: 81
# Total key metrics reports for BIRD: 13
# Total key metrics reports for INSW: 35
# Total key metrics reports for ARTNA: 115
# Total key metrics reports for CHRD: 58
# Total key metrics reports for EA: 139
# Total key metrics reports for HEAR: 57
# Total key metrics reports for THS: 78
# Total key metrics reports for EVCM: 15
# Total key metrics reports for CTVA: 23
# Total key metrics reports for GOCO: 18
# Total key metrics reports for DVAX: 83
# Total key metrics reports for KNTK: 27
# Total key metrics reports for DFIN: 35
# Total key metrics reports for RBBN: 95
# Total key metrics reports for TTMI: 95
# Total key metrics reports for BOOM: 139
# Total key metrics reports for HIBB: 110
# Total key metrics reports for ITW: 153
# Total key metrics reports for MRNA: 24
# Total key metrics reports for PRA: 131
# Total key metrics reports for TNYA: 15
# Total key metrics reports for VBTX: 44
# Total key metrics reports for STLD: 116
# Total key metrics reports for CEVA: 86
# Total key metrics reports for EL: 117
# Total key metrics reports for CVI: 71
# Total key metrics reports for SWKH: 99
# Total key metrics reports for ZVRA: 40
# Total key metrics reports for HSTM: 95
# Total key metrics reports for PTGX: 35
# Total key metrics reports for BMEA: 13
# Total key metrics reports for ALLO: 24
# Total key metrics reports for BCML: 44
# Total key metrics reports for GOGO: 52
# Total key metrics reports for UCBI: 95
# Total key metrics reports for FBRT: 43
# Total key metrics reports for FBMS: 95
# Total key metrics reports for SAGE: 43
# Total key metrics reports for TSVT: 14
# Total key metrics reports for BHR: 43
# Total key metrics reports for CRSP: 33
# Total key metrics reports for NWN: 153
# Total key metrics reports for NVAX: 111
# Total key metrics reports for HROW: 69
# Total key metrics reports for TXRH: 81
# Total key metrics reports for FE: 107
# Total key metrics reports for HAL: 154
# Total key metrics reports for CPSI: 91
# Total key metrics reports for LIN: 131
# Total key metrics reports for GTXI: 65
# Total key metrics reports for VCYT: 46
# Total key metrics reports for RJF: 153
# Total key metrics reports for RMAX: 45
# Total key metrics reports for TNGX: 14
# Total key metrics reports for BATRA: 44
# Total key metrics reports for TW: 23
# Total key metrics reports for RNA: 19
# Total key metrics reports for PHR: 23
# Total key metrics reports for AMRK: 43
# Total key metrics reports for PRU: 88
# Total key metrics reports for MBI: 147
# Total key metrics reports for IOSP: 103
# Total key metrics reports for DUK: 153
# Total key metrics reports for ABUS: 66
# Total key metrics reports for SYY: 154
# Total key metrics reports for ASML: 115
# Total key metrics reports for GWH: 15
# Total key metrics reports for TIO: 79
# Total key metrics reports for SKYX: 33
# Total key metrics reports for JCI: 154
# Total key metrics reports for ARCO: 55
# Total key metrics reports for GIS: 154
# Total key metrics reports for CHCO: 141
# Total key metrics reports for CHUY: 55
# Total key metrics reports for DZSI: 88
# Total key metrics reports for ODP: 147
# Total key metrics reports for KE: 43
# Total key metrics reports for NEXT: 37
# Total key metrics reports for TARO: 141
# Total key metrics reports for PSN: 23
# Total key metrics reports for SHOO: 124
# Total key metrics reports for NBTB: 131
# Total key metrics reports for SPHR: 19
# Total key metrics reports for BLFS: 140
# Total key metrics reports for POWW: 93
# Total key metrics reports for DB: 99
# Total key metrics reports for WRB: 154
# Total key metrics reports for KALU: 133
# Total key metrics reports for SGMT: 9
# Total key metrics reports for FTAI: 40
# Total key metrics reports for CRC: 43
# Total key metrics reports for EXPO: 137
# Total key metrics reports for VHI: 147
# Total key metrics reports for IGMS: 21
# Total key metrics reports for CPT: 123
# Total key metrics reports for DYN: 60
# Total key metrics reports for KRT: 19
# Total key metrics reports for ASIX: 35
# Total key metrics reports for PLRX: 19
# Total key metrics reports for PNC: 141
# Total key metrics reports for ARKO: 15
# Total key metrics reports for PRLB: 55
# No FLUT key metrics reports: kms=[]
# Total key metrics reports for AKAM: 99
# Total key metrics reports for SMCI: 78
# Total key metrics reports for PACB: 57
# Total key metrics reports for CHCT: 38
# Total key metrics reports for ALG: 127
# Total key metrics reports for PG: 154
# Total key metrics reports for HCKT: 103
# Total key metrics reports for PNW: 153
# Total key metrics reports for ULCC: 17
# Total key metrics reports for LQDA: 27
# Total key metrics reports for IHG: 61
# Total key metrics reports for MDLZ: 92
# Total key metrics reports for AES: 135
# Total key metrics reports for BCBP: 83
# Total key metrics reports for MEC: 23
# Total key metrics reports for HBI: 71
# Total key metrics reports for ANET: 43
# Total key metrics reports for ALIT: 14
# Total key metrics reports for ESSA: 72
# Total key metrics reports for CTRA: 140
# Total key metrics reports for TER: 154
# Total key metrics reports for GCO: 153
# Total key metrics reports for AGS: 40
# Total key metrics reports for KRMD: 94
# Total key metrics reports for BHE: 140
# Total key metrics reports for ADMA: 68
# Total key metrics reports for MVST: 20
# Total key metrics reports for SLAB: 95
# Total key metrics reports for MRTX: 75
# Total key metrics reports for EXLS: 79
# Total key metrics reports for APPF: 40
# Total key metrics reports for VIR: 22
# Total key metrics reports for OMC: 153
# Total key metrics reports for HBNC: 116
# Total key metrics reports for USCB: 14
# Total key metrics reports for VRSK: 63
# Total key metrics reports for AOS: 153
# Total key metrics reports for SJM: 153
# Total key metrics reports for CRK: 151
# Total key metrics reports for ITI: 153
# Total key metrics reports for SRI: 107
# Total key metrics reports for SEMR: 15
# Total key metrics reports for EVH: 39
# Total key metrics reports for BATRK: 44
# Total key metrics reports for NTCT: 99
# Total key metrics reports for NSP: 115
# Total key metrics reports for HMST: 54
# Total key metrics reports for CFB: 23
# Total key metrics reports for D: 153
# Total key metrics reports for GTN: 132
# Total key metrics reports for FCBC: 110
# Total key metrics reports for WHD: 28
# Total key metrics reports for PEB: 59
# Total key metrics reports for XRX: 154
# Total key metrics reports for ETSY: 39
# Total key metrics reports for CEIX: 31
# Total key metrics reports for WERN: 153
# Total key metrics reports for MHO: 121
# Total key metrics reports for AMCR: 43
# Total key metrics reports for WAL: 76
# Total key metrics reports for PLX: 109
# Total key metrics reports for EBC: 20
# Total key metrics reports for AWK: 140
# Total key metrics reports for DBI: 78
# Total key metrics reports for NFBK: 78
# Total key metrics reports for SWBI: 95
# Total key metrics reports for BFS: 123
# Total key metrics reports for INBX: 21
# Total key metrics reports for BG: 91
# Total key metrics reports for FARO: 107
# Total key metrics reports for CERS: 107
# Total key metrics reports for AIG: 153
# Total key metrics reports for FLNC: 15
# Total key metrics reports for PGC: 104
# Total key metrics reports for TRUP: 43
# Total key metrics reports for ANNX: 19
# Total key metrics reports for ALCO: 153
# Total key metrics reports for LBPH: 15
# Total key metrics reports for RILY: 67
# Total key metrics reports for NDAQ: 96
# Total key metrics reports for SSTI: 31
# Total key metrics reports for MMYT: 54
# Total key metrics reports for CCNE: 103
# Total key metrics reports for IT: 120
# Total key metrics reports for HTLF: 107
# Total key metrics reports for MKTX: 78
# Total key metrics reports for CIM: 63
# Total key metrics reports for LZB: 153
# Total key metrics reports for HII: 55
# Total key metrics reports for ABG: 87
# Total key metrics reports for BASE: 15
# Total key metrics reports for UFCS: 153
# Total key metrics reports for GPMT: 31
# Total key metrics reports for RHI: 154
# Total key metrics reports for IVT: 73
# Total key metrics reports for FOR: 66
# Total key metrics reports for GDYN: 20
# Total key metrics reports for PLYM: 50
# Total key metrics reports for ALKT: 18
# Total key metrics reports for WLLAW: 83
# Total key metrics reports for STNE: 25
# Total key metrics reports for YEXT: 33
# Total key metrics reports for WLY: 153
# Total key metrics reports for CABA: 21
# Total key metrics reports for TRMK: 140
# Total key metrics reports for OSUR: 140
# Total key metrics reports for VICI: 27
# No NQH4 key metrics reports: kms=[]
# Total key metrics reports for SFL: 79
# Total key metrics reports for PAYC: 45
# Total key metrics reports for HOUS: 55
# Total key metrics reports for SONO: 26
# Total key metrics reports for AMAL: 27
# Total key metrics reports for NSC: 153
# Total key metrics reports for ORIC: 19
# Total key metrics reports for MSCI: 75
# Total key metrics reports for DRI: 118
# Total key metrics reports for PBFS: 23
# Total key metrics reports for GOLF: 35
# Total key metrics reports for HUM: 135
# Total key metrics reports for HA: 119
# Total key metrics reports for ROST: 153
# Total key metrics reports for EWCZ: 15
# Total key metrics reports for GRWG: 34
# Total key metrics reports for ED: 153
# Total key metrics reports for REI: 70
# Total key metrics reports for CENX: 111
# Total key metrics reports for SXT: 153
# Total key metrics reports for GBCI: 152
# Total key metrics reports for FAST: 148
# Total key metrics reports for AROC: 93
# Total key metrics reports for CRCT: 16
# Total key metrics reports for XOMA: 153
# Total key metrics reports for HP: 154
# Total key metrics reports for ARM: 3
# Total key metrics reports for GNTY: 65
# Total key metrics reports for WALD: 7
# Total key metrics reports for DNLI: 28
# Total key metrics reports for OLMA: 16
# Total key metrics reports for FN: 63
# Total key metrics reports for CMTL: 141
# Total key metrics reports for DE: 153
# Total key metrics reports for AGO: 83
# Total key metrics reports for VKTX: 42
# Total key metrics reports for AKR: 119
# Total key metrics reports for SEAT: 14
# Total key metrics reports for GTLS: 129
# Total key metrics reports for ACET: 64
# Total key metrics reports for IRM: 108
# Total key metrics reports for B: 153
# Total key metrics reports for ARI: 57
# Total key metrics reports for COR: 116
# Total key metrics reports for PR: 31
# Total key metrics reports for FWRG: 15
# Total key metrics reports for FTCI: 15
# Total key metrics reports for AMPX: 10
# Total key metrics reports for IMVT: 19
# Total key metrics reports for BLNK: 67
# Total key metrics reports for EXC: 153
# Total key metrics reports for AFYA: 23
# Total key metrics reports for AMSF: 83
# Total key metrics reports for PXD: 107
# Total key metrics reports for MSFT: 154
# Total key metrics reports for TSN: 153
# Total key metrics reports for TWST: 23
# No WS key metrics reports: kms=[]
# Total key metrics reports for ANGO: 82
# Total key metrics reports for HAIN: 121
# Total key metrics reports for LPRO: 18
# Total key metrics reports for LEGH: 24
# Total key metrics reports for EVBG: 33
# Total key metrics reports for ULTA: 75
# Total key metrics reports for PIII: 12
# Total key metrics reports for SMAR: 27
# Total key metrics reports for INFA: 13
# Total key metrics reports for C: 140
# Total key metrics reports for POOL: 119
# Total key metrics reports for PWSC: 15
# Total key metrics reports for NAPA: 16
# Total key metrics reports for ALPN: 39
# Total key metrics reports for OBIO: 6
# Total key metrics reports for LYB: 57
# Total key metrics reports for SPWR: 77
# Total key metrics reports for FSR: 21
# Total key metrics reports for TCBX: 14
# Total key metrics reports for BOOT: 42
# Total key metrics reports for PLSE: 35
# Total key metrics reports for VLO: 153
# Total key metrics reports for TBPH: 43
# Total key metrics reports for AAN: 115
# ...
# Total key metrics reports for TFX: 153
# Total key metrics reports for HON: 153
# Total key metrics reports for RLJ: 55
# Total key metrics reports for UHG: 9
# Total key metrics reports for UFPI: 123
# Total key metrics reports for CSGS: 111
# Total key metrics reports for ALHC: 15
# Total key metrics reports for PAX: 16
# Total key metrics reports for DPZ: 82
# Total key metrics reports for KRUS: 22
# Total key metrics reports for TCI: 143
# Total key metrics reports for CRS: 154
# Total key metrics reports for SSNT: 79
# Total key metrics reports for NBR: 153
# Total key metrics reports for BELFB: 153
# Total key metrics reports for FL: 153
# Total key metrics reports for LANC: 153
# Total key metrics reports for LICY: 16
# Total key metrics reports for QTRX: 31
# Total key metrics reports for WFRD: 153
# Total key metrics reports for AVIR: 17
# Total key metrics reports for EGBN: 102
# Total key metrics reports for ATNI: 127
# Total key metrics reports for TCBI: 94
# Total key metrics reports for NEM: 153
# Total key metrics reports for CVCY: 91
# No   key metrics reports: kms=[]
# Total key metrics reports for BHB: 114
# Total key metrics reports for BZH: 124
# Total key metrics reports for BRZE: 13
# Total key metrics reports for VCTR: 31
# Total key metrics reports for ESS: 117
# Total key metrics reports for ORGN: 14
# Total key metrics reports for SUPN: 54
# Total key metrics reports for FITB: 153
# Total key metrics reports for COO: 153
# Total key metrics reports for LUNG: 17
# Total key metrics reports for STZ: 154
# Total key metrics reports for VRTX: 135
# Total key metrics reports for SLQT: 19
# Total key metrics reports for HCAT: 23
# Total key metrics reports for DFLI: 11
# Total key metrics reports for ARWR: 103
# Total key metrics reports for CNXN: 103
# Total key metrics reports for GLT: 153
# Total key metrics reports for AZEK: 21
# Total key metrics reports for EXPI: 58
# Total key metrics reports for IRWD: 60
# Total key metrics reports for VTRS: 152
# Total key metrics reports for CUE: 29
# Total key metrics reports for MCO: 103
# Total key metrics reports for MOD: 154
# Total key metrics reports for SCVL: 127
# Total key metrics reports for TREX: 103
# Total key metrics reports for RGA: 69
# Total key metrics reports for PUBM: 16
# Total key metrics reports for PINE: 21
# Total key metrics reports for EYEN: 28
# Total key metrics reports for SNDX: 43
# Total key metrics reports for EGRX: 44
# Total key metrics reports for TT: 153
# Total key metrics reports for PLMR: 23
# Total key metrics reports for VITL: 19
# Total key metrics reports for VSTO: 43
# Total key metrics reports for FERG: 55
# Total key metrics reports for METC: 32
# Total key metrics reports for LTH: 14
# Total key metrics reports for GRBK: 68
# No CRDA key metrics reports: kms=[]
# Total key metrics reports for CAL: 152
# Total key metrics reports for CCBG: 119
# Total key metrics reports for MRVL: 95
# Total key metrics reports for PCYO: 114
# Total key metrics reports for VRT: 27
# Total key metrics reports for CENTA: 126
# Total key metrics reports for LMND: 19
# Total key metrics reports for AEHR: 106
# Total key metrics reports for SAVE: 57
# Total key metrics reports for OSBC: 124
# Total key metrics reports for CIO: 44
# Total key metrics reports for PPL: 153
# Total key metrics reports for NOTE: 12
# Total key metrics reports for CXM: 16
# Total key metrics reports for VRCA: 27
# Total key metrics reports for KODK: 153
# Total key metrics reports for XRAY: 153
# Total key metrics reports for SBRA: 53
# Total key metrics reports for DD: 153
# Total key metrics reports for MARA: 52
# Total key metrics reports for KMB: 154
# Total key metrics reports for IDXX: 131
# Total key metrics reports for SSD: 123
# Total key metrics reports for CMCO: 113
# Total key metrics reports for OVLY: 84
# Total key metrics reports for TDG: 72
# Total key metrics reports for LNTH: 43
# Total key metrics reports for GNE: 52
# Total key metrics reports for IRBT: 73
# Total key metrics reports for ECPG: 99
# Total key metrics reports for AAL: 154
# Total key metrics reports for GBDC: 59
# Total key metrics reports for HEES: 73
# Total key metrics reports for SVC: 115
# Total key metrics reports for OLP: 153
# Total key metrics reports for VTLE: 53
# Total key metrics reports for BKE: 131
# Total key metrics reports for FEAM: 11
# Total key metrics reports for FMC: 151
# Total key metrics reports for VSH: 152
# Total key metrics reports for WDAY: 48
# Total key metrics reports for SRCE: 142
# Total key metrics reports for TOWN: 91
# Total key metrics reports for CMPR: 77
# Total key metrics reports for GEVO: 59
# Total key metrics reports for CODI: 71
# Total key metrics reports for IDT: 117
# Total key metrics reports for KIM: 129
# Total key metrics reports for CMG: 73
# No XTSLA key metrics reports: kms=[]
# Total key metrics reports for IMRX: 15
# Total key metrics reports for APLD: 44
# Total key metrics reports for GD: 154
# Total key metrics reports for CHD: 153
# Total key metrics reports for FI: 153
# Total key metrics reports for GATX: 154
# Total key metrics reports for RVTY: 153
# Total key metrics reports for INOD: 123
# Total key metrics reports for EIX: 153
# Total key metrics reports for FBP: 134
# Total key metrics reports for WAT: 115
# Total key metrics reports for TRDA: 13
# Total key metrics reports for UPBD: 119
# Total key metrics reports for STE: 134
# Total key metrics reports for TRVI: 23
# Total key metrics reports for TFC: 141
# Total key metrics reports for DNOW: 43
# Total key metrics reports for SNPS: 136
# Total key metrics reports for LMNR: 59
# Total key metrics reports for CYBR: 43
# Total key metrics reports for AKTS: 42
# Total key metrics reports for AGTI: 16
# Total key metrics reports for SBAC: 101
# Total key metrics reports for CHMG: 97
# Total key metrics reports for GILD: 133
# Total key metrics reports for EP: 95
# Total key metrics reports for TMO: 153
# Total key metrics reports for LLAP: 12
# Total key metrics reports for TJX: 151
# Total key metrics reports for IFF: 153
# Total key metrics reports for REX: 153
# Total key metrics reports for GES: 115
# Total key metrics reports for DK: 82
# Total key metrics reports for BKU: 55
# Total key metrics reports for SKY: 153
# Total key metrics reports for VTOL: 36
# Total key metrics reports for FIX: 107
# Total key metrics reports for PETS: 95
# No GBP key metrics reports: kms=[]
# Total key metrics reports for DAL: 153
# Total key metrics reports for SMR: 12
# Total key metrics reports for PRIM: 69
# Total key metrics reports for AMLX: 12
# Total key metrics reports for EEX: 31
# Total key metrics reports for LIND: 47
# Total key metrics reports for CSR: 106
# Total key metrics reports for TEL: 71
# Total key metrics reports for HRI: 65
# Total key metrics reports for INSE: 37
# Total key metrics reports for JBGS: 32
# Total key metrics reports for TRUE: 43
# Total key metrics reports for ACAD: 83
# Total key metrics reports for OXY: 153
# Total key metrics reports for BGFV: 87
# Total key metrics reports for LAUR: 92
# Total key metrics reports for GL: 152
# Total key metrics reports for IOVA: 63
# Total key metrics reports for CUBI: 52
# Total key metrics reports for MGNI: 44
# Total key metrics reports for NMRA: 11
# Total key metrics reports for SBOW: 153
# Total key metrics reports for NUS: 114
# Total key metrics reports for ATO: 153
# Total key metrics reports for RSG: 102
# Total key metrics reports for RAIN: 15
# Total key metrics reports for NTLA: 35
# Total key metrics reports for HST: 119
# Total key metrics reports for METCB: 32
# Total key metrics reports for ITGR: 93
# Total key metrics reports for WDFC: 154
# Total key metrics reports for SRE: 153
# Total key metrics reports for CWH: 35
# Total key metrics reports for AMT: 107
# Total key metrics reports for BWA: 127
# Total key metrics reports for THRM: 123
# Total key metrics reports for PGNY: 21
# Total key metrics reports for NICE: 115
# Total key metrics reports for TCBK: 132
# Total key metrics reports for NBN: 145
# Total key metrics reports for IRMD: 43
# Total key metrics reports for WFC: 152
# Total key metrics reports for MET: 101
# Total key metrics reports for EGO: 119
# Total key metrics reports for RDUS: 62
# Total key metrics reports for BEAM: 21
# Total key metrics reports for VRE: 119
# Total key metrics reports for QRVO: 45
# Total key metrics reports for BCRX: 119
# Total key metrics reports for PDFS: 91
# Total key metrics reports for ACCD: 20
# Total key metrics reports for VSEC: 153
# Total key metrics reports for CDXS: 62
# Total key metrics reports for PDCO: 134
# Total key metrics reports for PRVA: 15
# Total key metrics reports for EAT: 154
# Total key metrics reports for FSBW: 54
# Total key metrics reports for FATE: 45
# Total key metrics reports for SBH: 72
# Total key metrics reports for NJR: 153
# Total key metrics reports for PFG: 92
# Total key metrics reports for SRRK: 27
# Total key metrics reports for FIZZ: 130
# Total key metrics reports for NVR: 119
# Total key metrics reports for BCOV: 54
# Total key metrics reports for HRT: 13
# Total key metrics reports for SQSP: 15
# Total key metrics reports for NRGV: 12
# Total key metrics reports for NRG: 99
# Total key metrics reports for WEAV: 13
# Total key metrics reports for PWR: 107
# Total key metrics reports for DHT: 73
# Total key metrics reports for JBI: 14
# Total key metrics reports for HOMB: 79
# Total key metrics reports for AME: 153
# Total key metrics reports for OSK: 153
# Total key metrics reports for ATEN: 43
# Total key metrics reports for TWO: 70
# Total key metrics reports for K: 153
# Total key metrics reports for MITK: 143
# Total key metrics reports for GABC: 127
# Total key metrics reports for LYTS: 154
# Total key metrics reports for TBI: 112
# Total key metrics reports for MMC: 154
# Total key metrics reports for EMR: 153
# Total key metrics reports for VVX: 43
# Total key metrics reports for CZFS: 96
# Total key metrics reports for ECVT: 29
# Total key metrics reports for CYRX: 74
# Total key metrics reports for PCAR: 154
# Total key metrics reports for VZ: 155
# Total key metrics reports for ROG: 153
# Total key metrics reports for CMRE: 57
# Total key metrics reports for RDFN: 31
# Total key metrics reports for ENFN: 13
# Total key metrics reports for XOM: 153
# Total key metrics reports for MCBS: 36
# Total key metrics reports for ATSG: 86
# Total key metrics reports for FCFS: 136
# Total key metrics reports for CURV: 15
# Total key metrics reports for PDD: 27
# Total key metrics reports for DIOD: 152
# Total key metrics reports for LPG: 37
# Total key metrics reports for FLIC: 139
# Total key metrics reports for AHCO: 23
# Total key metrics reports for LOVE: 27
# Total key metrics reports for PANL: 42
# Total key metrics reports for FIHL: 6
# Total key metrics reports for NYMT: 82
# Total key metrics reports for KN: 43
# Total key metrics reports for SMTI: 88
# Total key metrics reports for PHAT: 21
# Total key metrics reports for SCPH: 28
# Total key metrics reports for OMGA: 15
# Total key metrics reports for SLVM: 13
# No EUR key metrics reports: kms=[]
# Total key metrics reports for KIDS: 32
# Total key metrics reports for CLDT: 55
# No - key metrics reports: kms=[]
# Total key metrics reports for ON: 96
# Total key metrics reports for DGICA: 151
# Total key metrics reports for TDUP: 15
# Total key metrics reports for LNW: 152
# Total key metrics reports for USNA: 119
# Total key metrics reports for WM: 147
# Total key metrics reports for MEI: 153
# No PBRA key metrics reports: kms=[]
# Total key metrics reports for MG: 61
# Total key metrics reports for DXCM: 75
# Total key metrics reports for HWKN: 152
# Total key metrics reports for IDYA: 23
# Total key metrics reports for WIRE: 131
# Total key metrics reports for SIX: 112
# Total key metrics reports for CFFI: 110
# Total key metrics reports for MTH: 140
# Total key metrics reports for CBOE: 59
# Total key metrics reports for PFMT: 51
# Total key metrics reports for SNOW: 17
# Total key metrics reports for LILAK: 38
# Total key metrics reports for MA: 87
# Total key metrics reports for KPTI: 46
# Total key metrics reports for SENEA: 153
# Total key metrics reports for SMBC: 116
# Total key metrics reports for PKE: 154
# Total key metrics reports for RXO: 10
# Total key metrics reports for ISPR: 7
# Total key metrics reports for SKYT: 15
# Total key metrics reports for SD: 75
# Total key metrics reports for ESE: 136
# Total key metrics reports for AROW: 153
# Total key metrics reports for COFS: 98
# Total key metrics reports for SKWD: 15
# Total key metrics reports for WNC: 135
# Total key metrics reports for ADRO: 27
# Total key metrics reports for MBC: 8
# Total key metrics reports for PWP: 16
# Total key metrics reports for ORRF: 100
# Total key metrics reports for SPSC: 61
# Total key metrics reports for TBBK: 79
# Total key metrics reports for XAIR: 32
# Total key metrics reports for SP: 99
# Total key metrics reports for HQY: 43
# Total key metrics reports for NVRO: 41
# Total key metrics reports for ALEX: 50
# Total key metrics reports for BBWI: 153
# Total key metrics reports for MD: 119
# Total key metrics reports for ANIP: 96
# Total key metrics reports for AZTA: 116
# Total key metrics reports for OTIS: 20
# Total key metrics reports for RSI: 15
# Total key metrics reports for CSTL: 23
# Total key metrics reports for FRBA: 33
# Total key metrics reports for BOX: 40
# Total key metrics reports for BA: 154
# Total key metrics reports for ZS: 27
# Total key metrics reports for TTD: 33
# Total key metrics reports for CSWI: 41
# Total key metrics reports for CVGI: 80
# Total key metrics reports for PTSI: 153
# Total key metrics reports for KTOS: 99
# Total key metrics reports for UMBF: 141
# Total key metrics reports for ARVN: 27
# Total key metrics reports for MGPI: 145
# Total key metrics reports for FDBC: 95
# Total key metrics reports for BALL: 153
# Total key metrics reports for OMCL: 92
# Total key metrics reports for KLAC: 154
# Total key metrics reports for FOXF: 47
# Total key metrics reports for AHH: 47
# Total key metrics reports for BLMN: 51
# Total key metrics reports for STR: 82
# Total key metrics reports for ATRO: 153
# Total key metrics reports for WEST: 11
# Total key metrics reports for TSLX: 51
# Total key metrics reports for STEL: 30
# Total key metrics reports for HOPE: 95
# Total key metrics reports for LESL: 17
# Total key metrics reports for FCNCA: 133
# Total key metrics reports for KELYA: 153
# Total key metrics reports for EHAB: 12
# Total key metrics reports for KFS: 111
# Total key metrics reports for CMI: 153
# Total key metrics reports for LSPD: 24
# Total key metrics reports for SPTN: 109
# Total key metrics reports for ORC: 51
# Total key metrics reports for OPK: 111
# Total key metrics reports for BSX: 131
# Total key metrics reports for ABCB: 119
# Total key metrics reports for TTWO: 107
# Total key metrics reports for HOV: 153
# Total key metrics reports for CMAX: 14
# Total key metrics reports for BRBS: 21
# Total key metrics reports for PDSB: 37
# Total key metrics reports for WLFC: 115
# Total key metrics reports for JBL: 133
# Total key metrics reports for ARCT: 46
# Total key metrics reports for OKE: 153
# Total key metrics reports for MKTW: 14
# Total key metrics reports for ZBH: 93
# Total key metrics reports for CBU: 153
# Total key metrics reports for VMEO: 17
# Total key metrics reports for UAL: 139
# Total key metrics reports for ATRC: 78
# Total key metrics reports for UNFI: 109
# Total key metrics reports for EXR: 82
# Total key metrics reports for CYTK: 83
# Total key metrics reports for NBHC: 53
# Total key metrics reports for TGAN: 25
# Total key metrics reports for UNF: 154
# Total key metrics reports for IBCP: 141
# Total key metrics reports for MCBC: 102
# Total key metrics reports for AVPT: 17
# Total key metrics reports for NRIM: 133
# Total key metrics reports for JNJ: 153
# Total key metrics reports for ARE: 108
# Total key metrics reports for PKBK: 83
# Total key metrics reports for LMB: 39
# Total key metrics reports for DOUG: 13
# Total key metrics reports for GEHC: 8
# Total key metrics reports for MAA: 119
# Total key metrics reports for FCF: 127
# Total key metrics reports for AON: 153
# Total key metrics reports for AMPS: 12
# Total key metrics reports for REFI: 10
# Total key metrics reports for FORR: 115
# Total key metrics reports for SWIM: 15
# Total key metrics reports for ACVA: 18
# Total key metrics reports for EFSC: 96
# Total key metrics reports for FTDR: 25
# Total key metrics reports for PRTH: 32
# Total key metrics reports for POWI: 111
# Total key metrics reports for FLYW: 16

# %%
keymetrics_all_df
# Out:
#                   calendarYear period  revenuePerShare  netIncomePerShare  \
# symbol date
# IAUX   2023-09-30         2023     Q3         0.046025          -0.014624
#        2023-06-30         2023     Q2         0.042610          -0.060136
#        2023-03-31         2023     Q1         0.018518          -0.053411
#        2001-12-31                 0.000000               0.000000
#
#                    receivablesTurnover  payablesTurnover  inventoryTurnover  \
# symbol date
# IAUX   2023-09-30            17.051613          1.326357           0.716237
#        2023-06-30             6.985794          1.258822           0.793360
#        2023-03-31             8.564972          0.889224           0.414934
#        2022-12-31            18.695024          1.422425           0.913759
#        2022-09-30            31.749012          3.366169           0.481113
# ...                                ...               ...                ...
# FLYW   2020-12-31             0.929486          2.124908           2.310200
#        2020-09-30             0.000000          0.000000           0.000000
#        2020-06-30             0.000000          0.000000           0.000000
#        2020-03-31             0.000000          0.000000           0.000000
#        2001-12-31                  NaN               NaN           0.000000
#
#                         roe  capexPerShare
# symbol date
# IAUX   2023-09-30 -0.009373      -0.040302
#        2023-06-30 -0.037492      -0.047609
#        2023-03-31 -0.036631      -0.041449
#        2022-12-31 -0.191766      -0.069289
#        2022-09-30 -0.028418      -0.077298
# ...                     ...            ...
# FLYW   2020-12-31  0.049302      -0.003692
#        2020-09-30  0.000000      -0.006183
#        2020-06-30  0.000000      -0.008169
#        2020-03-31  0.000000      -0.005981
#        2001-12-31       NaN       0.000000
#
# [213611 rows x 59 columns]

# %%
keymetrics_all_df.dtypes
# Out:
# calendarYear                               object
# period                                     object
# revenuePerShare                           float64
# netIncomePerShare                         float64
# operatingCashFlowPerShare                 float64
# freeCashFlowPerShare                      float64
# cashPerShare                              float64
# bookValuePerShare                         float64
# tangibleBookValuePerShare                 float64
# shareholdersEquityPerShare                float64
# interestDebtPerShare                      float64
# marketCap                                 float64
# enterpriseValue                           float64
# peRatio                                   float64
# priceToSalesRatio                         float64
# pocfratio                                 float64
# pfcfRatio                                 float64
# pbRatio                                   float64
# ptbRatio                                  float64
# evToSales                                 float64
# enterpriseValueOverEBITDA                 float64
# evToOperatingCashFlow                     float64
# evToFreeCashFlow                          float64
# earningsYield                             float64
# freeCashFlowYield                         float64
# debtToEquity                              float64
# debtToAssets                              float64
# netDebtToEBITDA                           float64
# currentRatio                              float64
# interestCoverage                          float64
# incomeQuality                             float64
# dividendYield                             float64
# payoutRatio                               float64
# salesGeneralAndAdministrativeToRevenue    float64
# researchAndDdevelopementToRevenue         float64
# intangiblesToTotalAssets                  float64
# capexToOperatingCashFlow                  float64
# capexToRevenue                            float64
# capexToDepreciation                       float64
# stockBasedCompensationToRevenue           float64
# grahamNumber                              float64
# roic                                      float64
# returnOnTangibleAssets                    float64
# grahamNetNet                              float64
# workingCapital                            float64
# tangibleAssetValue                        float64
# netCurrentAssetValue                      float64
# investedCapital                           float64
# averageReceivables                        float64
# averagePayables                            object
# averageInventory                          float64
# daysSalesOutstanding                      float64
# daysPayablesOutstanding                   float64
# daysOfInventoryOnHand                     float64
# receivablesTurnover                       float64
# payablesTurnover                          float64
# inventoryTurnover                         float64
# roe                                       float64
# capexPerShare                             float64
# dtype: object

# %%
len(keymetrics_all_df)
# Out:
# 213611

# %%
index, row = next(keymetrics_all_df.iterrows())

# %%
index
# Out:
# ('IAUX', Timestamp('2023-09-30 00:00:00'))

# %%
row['averagePayables']
# Out:
# 11083000.0

# %%
# prevent parquet serialization issues
keymetrics_all_df["averagePayables"] = pd.to_numeric(keymetrics_all_df["averagePayables"], dtype_backend="pyarrow")

# %%
keymetrics_all_df.index.names = ["Symbol", "Date"]
keymetrics_all_df.index.names

# %%
keymetrics_all_df = keymetrics_all_df.sort_index()
keymetrics_all_df
# Out:
#                   calendarYear period  revenuePerShare  netIncomePerShare  \
# Symbol Date
# A      1999-01-31         1999     Q1         4.102973           0.170000
#        1999-04-30         1999     Q2         4.480892           0.350000
#        1999-07-31         1999     Q3         4.637778           0.300000
#        1999-10-31         1999     Q4         5.576310           0.332574
#        2000-01-31         2000     Q1         5.116173           0.298405
# ...                        ...    ...              ...                ...
# ZYXI   2022-09-30         2022     Q3         1.091311           0.128082
#        2022-12-31         2022     Q4         1.310694           0.200129
#        2023-03-31         2023     Q1         1.149234           0.042759
#        2023-06-30         2023     Q2         1.233759           0.092054
#        2023-09-30         2023     Q3         1.404830           0.101151
#
#                    operatingCashFlowPerShare  freeCashFlowPerShare  \
# Symbol Date
# A      1999-01-31                        NaN                   NaN
#        1999-04-30                        NaN                   NaN
#        1999-07-31                        NaN                   NaN
#        1999-10-31                        NaN                   NaN
#        2000-01-31                   0.874715              0.667426
# ...                                      ...                   ...
# ZYXI   2022-09-30                   0.194791              0.191636
#        2022-12-31                   0.127753              0.125443
#        2023-03-31                   0.052706              0.047692
#        2023-06-30                   0.020338              0.014574
#        2023-09-30                   0.250288              0.243646
#
#                    cashPerShare  bookValuePerShare  tangibleBookValuePerShare  \
# Symbol Date
# A      1999-01-31           NaN                NaN                        NaN
#        1999-04-30           NaN                NaN                        NaN
#        1999-07-31           NaN                NaN                        NaN
#        1999-10-31      0.000000           7.703872                   7.703872
#        2000-01-31      3.211845          10.218679                  10.218679
# ...                         ...                ...                        ...
# ZYXI   2022-09-30      0.618514           1.713373                   0.932818
#        2022-12-31      0.540982           1.782093                   0.990708
#        2023-03-31      0.457622           1.757399                   0.960429
#        2023-06-30      1.612433           1.708989                   0.912584
#        2023-09-30      1.475922           1.648757                   0.838535
#
#                    shareholdersEquityPerShare  ...  averagePayables  \
# Symbol Date                                    ...
# A      1999-01-31                         NaN  ...             <NA>
#        1999-04-30                         NaN  ...             <NA>
#        1999-07-31                         NaN  ...             <NA>
#        1999-10-31                    7.703872  ...             <NA>
#        2000-01-31                   10.218679  ...      406500000.0
# ...                                       ...  ...              ...
# ZYXI   2022-09-30                    1.713373  ...        5187500.0
#        2022-12-31                    1.782093  ...        5370000.0
#        2023-03-31                    1.757399  ...        5625500.0
#        2023-06-30                    1.708989  ...        5790000.0
#        2023-09-30                    1.648757  ...        6990000.0
#
#                    averageInventory  daysSalesOutstanding  \
# Symbol Date
# A      1999-01-31               NaN                   NaN
#        1999-04-30               NaN                   NaN
#        1999-07-31               NaN                   NaN
#        1999-10-31               NaN             60.110294
#        2000-01-31      1.533000e+09             57.902939
# ...                             ...                   ...
# ZYXI   2022-09-30      1.446900e+07             61.452312
#        2022-12-31      1.392500e+07             64.658744
#        2023-03-31      1.383400e+07             68.423050
#        2023-06-30      1.425450e+07             65.984383
#        2023-09-30      1.425550e+07             60.020435
#
#                    daysPayablesOutstanding  daysOfInventoryOnHand  \
# Symbol Date
# A      1999-01-31                 0.000000               0.000000
#        1999-04-30                 0.000000               0.000000
#        1999-07-31                 0.000000               0.000000
#        1999-10-31                 0.000000               0.000000
#        2000-01-31                23.508621             121.577586
# ...                                    ...                    ...
# ZYXI   2022-09-30                55.119771             154.086521
#        2022-12-31                53.695143             129.267150
#        2023-03-31                54.860287             137.723595
#        2023-06-30                57.560397             139.047670
#        2023-09-30                75.840050             133.648069
#
#                    receivablesTurnover  payablesTurnover  inventoryTurnover  \
# Symbol Date
# A      1999-01-31             0.000000          0.000000           0.000000
#        1999-04-30             0.000000          0.000000           0.000000
#        1999-07-31             0.000000          0.000000           0.000000
#        1999-10-31             1.497248          0.000000           0.000000
#        2000-01-31             1.554325          3.828383           0.740268
# ...                                ...               ...                ...
# ZYXI   2022-09-30             1.464550          1.632808           0.584087
#        2022-12-31             1.391923          1.676129           0.696233
#        2023-03-31             1.315346          1.640531           0.653483
#        2023-06-30             1.363959          1.563575           0.647260
#        2023-09-30             1.499489          1.186708           0.673410
#
#                         roe  capexPerShare
# Symbol Date
# A      1999-01-31  0.000000            NaN
#        1999-04-30  0.000000            NaN
#        1999-07-31  0.000000            NaN
#        1999-10-31  0.043170            NaN
#        2000-01-31  0.029202      -0.207289
# ...                     ...            ...
# ZYXI   2022-09-30  0.074754      -0.003154
#        2022-12-31  0.112300      -0.002310
#        2023-03-31  0.024331      -0.005014
#        2023-06-30  0.053865      -0.005764
#        2023-09-30  0.061350      -0.006642
#
# [213611 rows x 59 columns]

# %%
# kms_file = 'data/keymetrics_history.csv.bz2'
# keymetrics_all_df.to_csv(kms_file)

kms_file = 'data/data-3rd-party/keymetrics_history.parquet'

# %%
keymetrics_all_df.to_parquet(kms_file, engine="pyarrow")

# %%
temp_kms_df = pd.read_parquet(kms_file)
temp_kms_df
# Out:
#                   calendarYear period  revenuePerShare  netIncomePerShare  \
# Symbol Date
# A      1999-01-31         1999     Q1         4.102973           0.170000
#        1999-04-30         1999     Q2         4.480892           0.350000
#        1999-07-31         1999     Q3         4.637778           0.300000
#        1999-10-31         1999     Q4         5.576310           0.332574
#        2000-01-31         2000     Q1         5.116173           0.298405
# ...                        ...    ...              ...                ...
# ZYXI   2022-09-30         2022     Q3         1.091311           0.128082
#        2022-12-31         2022     Q4         1.310694           0.200129
#        2023-03-31         2023     Q1         1.149234           0.042759
#        2023-06-30         2023     Q2         1.233759           0.092054
#        2023-09-30         2023     Q3         1.404830           0.101151
#
#                    operatingCashFlowPerShare  freeCashFlowPerShare  \
# Symbol Date
# A      1999-01-31                        NaN                   NaN
#        1999-04-30                        NaN                   NaN
#        1999-07-31                        NaN                   NaN
#        1999-10-31                        NaN                   NaN
#        2000-01-31                   0.874715              0.667426
# ...                                      ...                   ...
# ZYXI   2022-09-30                   0.194791              0.191636
#        2022-12-31                   0.127753              0.125443
#        2023-03-31                   0.052706              0.047692
#        1999-10-31  0.043170            NaN
#        2000-01-31  0.029202      -0.207289
# ...                     ...            ...
# ZYXI   2022-09-30  0.074754      -0.003154
#        2022-12-31  0.112300      -0.002310
#        2023-03-31  0.024331      -0.005014
#        2023-06-30  0.053865      -0.005764
#        2023-09-30  0.061350      -0.006642
#
# [213611 rows x 59 columns]

# %% [markdown]
# ## Prepare institutional ownership data

# %%
from fmpsdk.settings import DEFAULT_LIMIT, SEC_RSS_FEEDS_FILENAME, BASE_URL_v3
from fmpsdk.url_methods import __return_json_v4
import typing


def institutional_symbol_ownership(
    apikey: str,
    symbol: str,
    limit: int,
    includeCurrentQuarter: bool = False,
) -> typing.Optional[typing.List[typing.Dict]]:
    """
    Query FMP /institutional-ownership/ API.

    :param apikey: Your API key.
    :param symbol: Company ticker.
    :param limit: up to how many quarterly reports to return.
    :param includeCurrentQuarter: Whether to include any available data in the current quarter.
    :return: A list of dictionaries.
    """
    path = f"institutional-ownership/symbol-ownership"
    query_vars = {"symbol": symbol, "apikey": apikey, "includeCurrentQuarter": includeCurrentQuarter, "limit": limit}
    return __return_json_v4(path=path, query_vars=query_vars)

# %%
inst_ownership_all_df = pd.DataFrame()
for ticker in stocks_ticker_set:
    inst_ownership = institutional_symbol_ownership(apikey=FMP_API_KEY, symbol=ticker, limit=-1, includeCurrentQuarter=False)
    # print("inst_ownership: ", inst_ownership)
    if inst_ownership is not None and len(inst_ownership) > 0:
        inst_ownership_df = pd.DataFrame(inst_ownership)
        inst_ownership_df['date'] = pd.to_datetime(inst_ownership_df['date'])
        inst_ownership_df = inst_ownership_df.set_index(['symbol', 'date'])
        # print(f"Institutional ownership for {ticker} # columns: \n{len(inst_ownership_df.columns)}")
        n_iown = len(inst_ownership_df)
        print(f"Total institutional ownership reports for {ticker}: {n_iown}")
        inst_ownership_all_df = pd.concat([inst_ownership_all_df, inst_ownership_df])
        # print(f"Institutional ownership concatenated {ticker} # columns: \n{inst_ownership_all_df.columns}")
    else:
        print(f"No {ticker} institutional ownership reports: inst_ownership={inst_ownership}")
# Out:
# Total institutional ownership reports for AAT: 51
# No APGE institutional ownership reports: inst_ownership=[]
# Total institutional ownership reports for MLNK: 9
# Total institutional ownership reports for VIAV: 34
# Total institutional ownership reports for QTRX: 24
# Total institutional ownership reports for SKIN: 11
# No ATMU institutional ownership reports: inst_ownership=[]
# Total institutional ownership reports for CMCSA: 84
# Total institutional ownership reports for LSPD: 10
# Total institutional ownership reports for OMER: 56
# Total institutional ownership reports for EU: 7
# Total institutional ownership reports for NEWT: 37
# Total institutional ownership reports for MWA: 70
# Total institutional ownership reports for CEVA: 80
# Total institutional ownership reports for EMBC: 8
# Total institutional ownership reports for BSVN: 66
# Total institutional ownership reports for TBBK: 76
# Total institutional ownership reports for FOSL: 54
# Total institutional ownership reports for INSM: 51
# Total institutional ownership reports for TMHC: 43
# Total institutional ownership reports for VTOL: 14
# Total institutional ownership reports for FANG: 44
# Total institutional ownership reports for ELME: 19
# Total institutional ownership reports for VFC: 100
# Total institutional ownership reports for RDFN: 25
# Total institutional ownership reports for WDC: 99
# Total institutional ownership reports for NRG: 79
# Total institutional ownership reports for LGFB: 35
# Total institutional ownership reports for DPZ: 77
# Total institutional ownership reports for HST: 99
# Total institutional ownership reports for DB: 89
# Total institutional ownership reports for SWX: 100
# Total institutional ownership reports for IMRX: 9
# Total institutional ownership reports for DUK: 63
# Total institutional ownership reports for BAC: 104
# Total institutional ownership reports for FLNC: 8
# Total institutional ownership reports for EPAC: 16
# Total institutional ownership reports for ORGO: 20
# Total institutional ownership reports for GRC: 99
# Total institutional ownership reports for MDT: 100
# Total institutional ownership reports for TRMK: 99
# Total institutional ownership reports for AMAL: 11
# Total institutional ownership reports for BECN: 77
# Total institutional ownership reports for HUMA: 9
# Total institutional ownership reports for STEM: 19
# Total institutional ownership reports for LAW: 9
# Total institutional ownership reports for OTTR: 99
# Total institutional ownership reports for CYBR: 38

# %%
inst_own_df = inst_ownership_all_df.copy()

# %%
inst_own_df
# Out:
#                        cik  investorsHolding  lastInvestorsHolding  \
# symbol date
# AAT    2023-09-30  1500217               179                   173
#        2023-06-30  1500217               173                   190
#        2023-03-31  1500217               190                   189
#        2022-12-31  1500217               189                   181
#        2022-09-30  1500217               181                   199
# ...                    ...               ...                   ...
# CYBR   2015-06-30  1598110               157                    97
#        2015-03-31  1598110                97                    56
#        2014-12-31  1598110                56                    44
#        2014-09-30  1598110                44                     0
#        2010-06-30  1598110                 1                     0
#
#                    investorsHoldingChange  numberOf13Fshares  \
# symbol date
# AAT    2023-09-30                       6           53143863
#        2023-06-30                     -17           54106944
#        2023-03-31                       1           55578800
#        2022-12-31                       8           56689571
#        2022-09-30                     -18           56532348
# ...                                   ...                ...
# CYBR   2015-06-30                      60           14394181
#        2015-03-31                      41            9779375
#        2014-12-31                      12            7711977
#        2014-09-30                      44            7571273
#        2010-06-30                       1                175
#
#                    lastNumberOf13Fshares  numberOf13FsharesChange  \
# symbol date
# AAT    2023-09-30               54106944                  -963081
#        2023-06-30               55578800                 -1471856
#        2023-03-31               56689571                 -1110771
#        2022-12-31               56532348                   157223
#        2022-09-30               57748945                 -1216597
# ...                                  ...                      ...
# CYBR   2015-06-30                9779375                  4614806
#        2015-03-31                7711977                  2067398
#        2014-12-31                7571273                   140704
#        2014-09-30                      0                  7571273
#        2010-06-30                      0                      175
#
#                    totalInvested  lastTotalInvested  totalInvestedChange  ...  \
# symbol date                                                               ...
# AAT    2023-09-30   1.031812e+09       1.686976e+09           -655164822  ...
#        2023-06-30   1.686976e+09       1.962058e+09           -275081870  ...
#        2023-03-31   1.962058e+09       1.505419e+09            456639094  ...
#        2022-12-31   1.505419e+09       1.454094e+09             51324839  ...
#        2022-09-30   1.454094e+09       1.715183e+09           -261088756  ...
# ...                          ...                ...                  ...  ...
# CYBR   2015-06-30   9.032510e+08       5.429883e+08            360262723  ...
#        2015-03-31   5.429883e+08       3.056906e+08            237297670  ...
#        2014-12-31   3.056906e+08       2.423507e+08             63339941  ...
#        2014-09-30   2.423507e+08       0.000000e+00            242350682  ...
#        2010-06-30   5.238000e+03       0.000000e+00                 5238  ...
#
#                    reducedPositionsChange  totalCalls  lastTotalCalls  \
# symbol date
# AAT    2023-09-30                       8     51500.0         12300.0
#        2023-06-30                      18     12300.0             0.0
#        2023-03-31                      -3         0.0             0.0
#        2022-12-31                     -17         0.0             0.0
#        2022-09-30                       6         0.0             0.0
# ...                                   ...         ...             ...
# CYBR   2015-06-30                       7    314100.0         97900.0
#        2015-03-31                      11     97900.0         10000.0
#        2014-12-31                       5     10000.0             0.0
#        2014-09-30                       0         0.0             0.0
#        2010-06-30                       0         0.0             0.0
#
#                    totalCallsChange  totalPuts  lastTotalPuts  \
# symbol date
# AAT    2023-09-30             39200     1500.0         9000.0
#        2023-06-30             12300     9000.0            0.0
#        2023-03-31                 0        0.0            0.0
#        2022-12-31                 0        0.0            0.0
#        2022-09-30                 0        0.0            0.0
# ...                             ...        ...            ...
# CYBR   2015-06-30            216200   399970.0       193754.0
#        2015-03-31             87900   193754.0         6600.0
#        2014-12-31             10000     6600.0            0.0
#        2014-09-30                 0        0.0            0.0
#        2010-06-30                 0        0.0            0.0
#
#                    totalPutsChange  putCallRatio  lastPutCallRatio  \
# symbol date
# AAT    2023-09-30            -7500        0.0291            0.7317
#        2023-06-30             9000        0.7317            0.0000
#        2023-03-31                0        0.0000            0.0000
#        2022-12-31                0        0.0000            0.0000
#        2022-09-30                0        0.0000            0.0000
# ...                            ...           ...               ...
# CYBR   2015-06-30           206216        1.2734            1.9791
#        2015-03-31           187154        1.9791            0.6600
#        2014-12-31             6600        0.6600            0.0000
#        2014-09-30                0        0.0000            0.0000
#        2010-06-30                0        0.0000            0.0000
#
#                    putCallRatioChange
# symbol date
# AAT    2023-09-30            -70.2581
#        2023-06-30             73.1707
#        2023-03-31              0.0000
#        2022-12-31              0.0000
#        2022-09-30              0.0000
# ...                               ...
# CYBR   2015-06-30            -70.5717
#        2015-03-31            131.9101
#        2014-12-31             66.0000
#        2014-09-30              0.0000
#        2010-06-30              0.0000
#
# [136337 rows x 34 columns]

# %%
# prevent parquet serialization issues
inst_own_df["totalInvestedChange"] = pd.to_numeric(inst_own_df["totalInvestedChange"], dtype_backend="pyarrow", downcast = 'integer')

# %%
def find_bad_cell():
    for index, row in inst_own_df.iterrows():
        try:
            x = row["totalPutsChange"]
            assert isinstance(x, int)
        except Exception as e:
            print(f"Unable to convert to numeric type value:({x}), type({type(x)}), index({index}, \nerror:{e}\nrow:{row})")
            break

# %%
find_bad_cell()

# %%
type(inst_own_df["totalInvestedChange"][0])
# Out:
# int

# %%
# clean up bad data from the third party source feed
inst_own_df["totalInvestedChange"] = inst_own_df["totalInvestedChange"].astype("float64")
inst_own_df["totalInvestedChange"] = inst_own_df["totalInvestedChange"].astype("int64")

# %%
inst_own_df["cik"] = inst_own_df["cik"].replace('', -1)
inst_own_df["cik"] = inst_own_df["cik"].astype("int64")

# %%
inst_own_df["totalPutsChange"] = inst_own_df["totalPutsChange"].astype("float64")
inst_own_df["totalPutsChange"] = inst_own_df["totalPutsChange"].astype("int64")
# inst_own_df["totalPutsChange"] = pd.to_numeric(inst_own_df["totalPutsChange"], dtype_backend="pyarrow", downcast = 'integer')

# %%
inst_own_df["totalCallsChange"] = inst_own_df["totalCallsChange"].astype("float64")
inst_own_df["totalCallsChange"] = inst_own_df["totalCallsChange"].astype("int64")

# %%
inst_own_df.dtypes
# Out:
# cik                           int64
# investorsHolding              int64
# lastInvestorsHolding          int64
# investorsHoldingChange        int64
# numberOf13Fshares             int64
# lastNumberOf13Fshares         int64
# numberOf13FsharesChange       int64
# totalInvested               float64
# lastTotalInvested           float64
# totalInvestedChange           int64
# ownershipPercent            float64
# lastOwnershipPercent        float64
# ownershipPercentChange      float64
# newPositions                  int64
# lastNewPositions              int64
# newPositionsChange            int64
# increasedPositions            int64
# lastIncreasedPositions        int64
# increasedPositionsChange      int64
# closedPositions               int64
# lastClosedPositions           int64
# closedPositionsChange         int64
# reducedPositions              int64
# lastReducedPositions          int64
# reducedPositionsChange        int64
# totalCalls                  float64
# lastTotalCalls              float64
# totalCallsChange              int64
# totalPuts                   float64
# lastTotalPuts               float64
# totalPutsChange               int64
# putCallRatio                float64
# lastPutCallRatio            float64
# putCallRatioChange          float64
# dtype: object

# %%
# inst_ownership_file = 'data/institutional_symbol_ownership.csv.bz2'
# inst_ownership_all_df.to_csv(inst_ownership_file)

# %%
inst_own_df = inst_own_df.sort_index()
inst_own_df
# Out:
#                        cik  investorsHolding  lastInvestorsHolding  \
# symbol date
# A      1999-12-31  1090872                15                     0
#        2000-03-31  1090872                19                    15
#        2000-06-30  1090872                99                    19
#        2000-09-30  1090872                77                    99
#        2000-12-31  1090872                81                    77
# ...                    ...               ...                   ...
# ZYXI   2022-09-30   846475               115                   103
#        2022-12-31   846475               129                   115
#        2023-03-31   846475               129                   129
#        2023-06-30   846475               147                   129
#        2023-09-30   846475               124                   147
#
#                    investorsHoldingChange  numberOf13Fshares  \
# symbol date
# A      1999-12-31                      15           16350001
#        2000-03-31                       4           19655547
#        2000-06-30                      80           61180271
#        2000-09-30                     -22           60125149
#        2000-12-31                       4           36801893
# ...                                   ...                ...
# ZYXI   2022-09-30                      12           10539839
#        2022-12-31                      14           10286348
#        2023-03-31                       0           10881276
#        2023-06-30                      18           12911045
#        2023-09-30                     -23           10187922
#
#                    lastNumberOf13Fshares  numberOf13FsharesChange  \
# symbol date
# A      1999-12-31                      0                 16350001
#        2000-03-31               16350001                  3305546
#        2000-06-30               19655547                 41524724
#        2000-09-30               61180271                 -1055122
#        2000-12-31               60125149                -23323256
# ...                                  ...                      ...
# ZYXI   2022-09-30               11010023                  -470184
#        2022-12-31               10539839                  -253491
#        2023-03-31               10286348                   594928
#        2023-06-30               10881276                  2029769
#        2023-09-30               12911045                 -2723123
#
#                    totalInvested  lastTotalInvested  totalInvestedChange  ...  \
# symbol date                                                               ...
# A      1999-12-31      1259479.0                0.0              1259479  ...
#        2000-03-31     10596271.0          1259479.0              9336792  ...
#        2000-06-30     19609932.0         10596271.0              9013661  ...
#        2000-09-30      5746041.0         19609932.0            -13863891  ...
#        2000-12-31      5956761.0          5746041.0               210720  ...
# ...                          ...                ...                  ...  ...
# ZYXI   2022-09-30     96250915.0         87843124.0              8407791  ...
#        2022-12-31    268096710.0         96250915.0            171845795  ...
#        2023-03-31    130575312.0        268096710.0           -137521398  ...
#        2023-06-30    170590938.0        130575312.0             40015626  ...
#        2023-09-30     81505648.0        170590938.0            -89085290  ...
#
#                    reducedPositionsChange  totalCalls  lastTotalCalls  \
# symbol date
# A      1999-12-31                       0       200.0             0.0
#        2000-03-31                       3         0.0           200.0
#        2000-06-30                       0       500.0             0.0
#        2000-09-30                      25     85000.0           500.0
#        2000-12-31                       4     85000.0         85000.0
# ...                                   ...         ...             ...
# ZYXI   2022-09-30                      -7     18000.0         29510.0
#        2022-12-31                      15     22500.0         18000.0
#        2023-03-31                     -11         0.0         22500.0
#        2023-06-30                      -3      1400.0             0.0
#        2023-09-30                       7       100.0          1400.0
#
#                    totalCallsChange  totalPuts  lastTotalPuts  \
# symbol date
# A      1999-12-31               200        0.0            0.0
#        2000-03-31              -200     1000.0            0.0
#        2000-06-30               500     1700.0         1000.0
#        2000-09-30             84500    20000.0         1700.0
#        2000-12-31                 0    20200.0        20000.0
# ...                             ...        ...            ...
# ZYXI   2022-09-30            -11510    14200.0        10730.0
#        2022-12-31              4500     2200.0        14200.0
#        2023-03-31            -22500   333200.0         2200.0
#        2023-06-30              1400    17000.0       333200.0
#        2023-09-30             -1300   510400.0        17000.0
#
#                    totalPutsChange  putCallRatio  lastPutCallRatio  \
# symbol date
# A      1999-12-31                0        0.0000            0.0000
#        2000-03-31             1000        0.0000            0.0000
#        2000-06-30              700        3.4000            0.0000
#        2000-09-30            18300        0.2353            3.4000
#        2000-12-31              200        0.2376            0.2353
# ...                            ...           ...               ...
# ZYXI   2022-09-30             3470        0.7889            0.3636
#        2022-12-31           -12000        0.0978            0.7889
#        2023-03-31           331000        0.0000            0.0978
#        2023-06-30          -316200       12.1429            0.0000
#        2023-09-30           493400     5104.0000           12.1429
#
#                    putCallRatioChange
# symbol date
# A      1999-12-31              0.0000
#        2000-03-31              0.0000
#        2000-06-30            340.0000
#        2000-09-30           -316.4706
#        2000-12-31              0.2353
# ...                               ...
# ZYXI   2022-09-30             42.5283
#        2022-12-31            -69.1111
#        2023-03-31             -9.7778
#        2023-06-30           1214.2857
#        2023-09-30         509185.7143
#
# [136337 rows x 34 columns]

# %%
inst_own_df.index.names = ["Symbol", "Date"]
inst_own_df.index.names
# Out:
# FrozenList(['Symbol', 'Date'])

# %%
inst_ownership_file = 'data/data-3rd-party/institutional_symbol_ownership.parquet'

# %%
inst_own_df.to_parquet(inst_ownership_file, engine="pyarrow")

# %%
tmp_int_own_df = pd.read_parquet(inst_ownership_file)
tmp_int_own_df
# Out:
#                        cik  investorsHolding  lastInvestorsHolding  \
# symbol date
# AAT    2023-09-30  1500217               179                   173
#        2023-06-30  1500217               173                   190
#        2023-03-31  1500217               190                   189
#        2022-12-31  1500217               189                   181
#        2022-09-30  1500217               181                   199
# ...                    ...               ...                   ...
# CYBR   2015-06-30  1598110               157                    97
#        2015-03-31  1598110                97                    56
#        2014-12-31  1598110                56                    44
#        2014-09-30  1598110                44                     0
# ...                            ...           ...               ...
# CYBR   2015-06-30           206216        1.2734            1.9791
#        2015-03-31           187154        1.9791            0.6600
#        2014-12-31             6600        0.6600            0.0000
#        2014-09-30                0        0.0000            0.0000
#        2010-06-30                0        0.0000            0.0000
#
#                    putCallRatioChange
# symbol date
# AAT    2023-09-30            -70.2581
#        2023-06-30             73.1707
#        2023-03-31              0.0000
#        2022-12-31              0.0000
#        2022-09-30              0.0000
# ...                               ...
# CYBR   2015-06-30            -70.5717
#        2015-03-31            131.9101
#        2014-12-31             66.0000
#        2014-09-30              0.0000
#        2010-06-30              0.0000
#
# [136337 rows x 34 columns]

# %% [markdown]
# ## Prepare forward looking analyst estimates to be used as future covariates

# %%
DEFAULT_LIMIT=-1
import typing
from fmpsdk.url_methods import __return_json_v3, __validate_period


def analyst_estimates(
    apikey: str,
    symbol: str,
    period: str = "annual",
    limit: int = DEFAULT_LIMIT
) -> typing.Optional[typing.List[typing.Dict]]:
    """
    Query FMP /analyst-estimates/ API.

    :param apikey: Your API key.
    :param symbol: Company ticker.
    :param period: 'annual' or 'quarter'
    :param limit: Number of rows to return.
    :return: A list of dictionaries.
    """
    path = f"/analyst-estimates/{symbol}"
    query_vars = {
        "apikey": apikey,
        "symbol": symbol,
        "period": __validate_period(value=period),
        "limit": limit,
    }
    return __return_json_v3(path=path, query_vars=query_vars)

# %%
def fetch_estimates(period=None):
    assert period in ['quarter', 'annual']
    estimates_all_df = pd.DataFrame()
    for ticker in stocks_ticker_set: # ['ALTR']:
        est = analyst_estimates(apikey=FMP_API_KEY, symbol=ticker, period=period, limit=-1)
        # print('est:', est)
        if est is not None and len(est) > 0:
            est_df = pd.DataFrame(est)
            est_df['date'] = pd.to_datetime(est_df['date'])
            est_df = est_df.set_index(['symbol', 'date'])
            # print(f"Analyst estimates for {ticker} sample: \n{est_df.columns}")
            estimates_all_df = pd.concat([estimates_all_df, est_df])
            # print(f"Key metrics concatenated {ticker}: \n{estimates_all_df.columns}")
            n_est = len(est_df)
            print(f"{n_est} total {ticker} {period} analyst estimates reports")
        else:
            print(f"No {ticker} {period} analyst estimates reports: est={est}")

    return estimates_all_df

# %%
# 'TW' in stocks_ticker_set

# %%
for p in ['annual', 'quarter']:
    est_file_name= f'data/data-3rd-party/analyst_estimates_{p}.parquet'
    estimates_all_df = fetch_estimates(p)
    estimates_all_df = estimates_all_df.sort_index()
    estimates_all_df.index.names = ["Symbol", "Date"]
    # est_file_name= f'data/analyst_estimates_{p}.csv.bz2'
    # estimates_all_df.to_csv(est_file_name)
    estimates_all_df.to_parquet(est_file_name)
    print(f'all {p} estimates count:', len(estimates_all_df.index))
# Out:
# all annual estimates count: 43626
# all quarter estimates count: 149305

# %%
tmp_est_dict = {}
for p in ['annual', 'quarter']:
    est_file_name= f'data/data-3rd-party/analyst_estimates_{p}.parquet'
    tmp_est_dict[p] = pd.read_parquet(est_file_name)
    print(f'all {p} estimates count:', len(tmp_est_dict[p]))
# Out:
# all annual estimates count: 43626
# all quarter estimates count: 149305

# %%
#        2000-05-01             318181818.0              477272727.0
#        2000-07-31             517650000.0              776475000.0
#        2000-10-31             578736234.0              868104352.0
#        2001-01-31             429333333.0              644000000.0
# ...                                   ...                      ...
# ZYXI   2023-09-30              13338072.0               20007108.0
#        2023-12-30              17648237.0               26472355.0
#        2024-03-30              27145197.0               40717796.0
#        2024-06-30              46568614.0               57364896.0
#        2024-09-30              53221274.0               65559881.0
#
#                    estimatedSgaExpenseAvg  estimatedEpsAvg  estimatedEpsHigh  \
# Symbol Date
# A      2000-01-31             363200119.0          0.22000           0.24129
#        2000-05-01             397727272.0          0.32000           0.35097
#        2000-07-31             647062500.0          0.20000           0.21935
#        2000-10-31             723420293.0          0.54000           0.59226
#        2001-01-31             536666666.0          0.45000           0.49355
# ...                                   ...              ...               ...
# ZYXI   2023-09-30              16672590.0          0.09300           0.10000
#        2023-12-30              22060296.0          0.20000           0.23000
#        2024-03-30              33931496.0          0.17000           0.19550
#        2024-06-30              51969240.0          1.34259           1.54398
#        2024-09-30              59393417.0          1.54141           1.77262
#
#                    estimatedEpsLow  numberAnalystEstimatedRevenue  \
# Symbol Date
# A      2000-01-31          0.20253                            3.0
#        2000-05-01          0.29459                            3.0
#        2000-07-31          0.18412                            3.0
#        2000-10-31          0.49712                            3.0
#        2001-01-31          0.41427                            2.0
# ...                            ...                            ...
# ZYXI   2023-09-30          0.09000                            3.0
#        2023-12-30          0.18000                            2.0
#        2024-03-30          0.15300                            1.0
#        2024-06-30          1.20833                            0.0
#        2024-09-30          1.38727                            0.0
#
#                    numberAnalystsEstimatedEps
# Symbol Date
# A      2000-01-31                         6.0
#        2000-05-01                         9.0
#        2000-07-31                         4.0
#        2000-10-31                         4.0
#        2001-01-31                         8.0
# ...                                       ...
# ZYXI   2023-09-30                         3.0
#        2023-12-30                         2.0
#        2024-03-30                         1.0
#        2024-06-30                         0.0
#        2024-09-30                         0.0
#
# [149305 rows x 20 columns]

# %% [markdown]
# ## Upload raw data to hf hub

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from huggingface_hub import snapshot_download, upload_folder, create_repo
from canswim.hfhub import HFHub

# prefix for HF Hub dataset repo
repo_id = "ivelin/canswim"
private=True

load_dotenv(override=True)

HF_TOKEN=os.getenv("HF_TOKEN")

print(f'HF_TOKEN={HF_TOKEN!= None}')
# Out:
# HF_TOKEN=True

# %%
# Create repo if not existing yet
repo_info = create_repo(
    repo_id=repo_id, repo_type="dataset", private=private, exist_ok=True, token=HF_TOKEN
)
print(f"repo_info: ", repo_info)
data_path = Path("data")
upload_folder(
    repo_id=repo_id,
    # path_in_repo="data-3rd-party",
    repo_type="dataset",
    folder_path=data_path,
    token=HF_TOKEN,
)
# Out:
# repo_info:  https://huggingface.co/datasets/ivelin/canswim
# sectors.parquet:   0%|          | 0.00/3.12M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/ivelin/canswim/commit/6d3a1c9c577bd79abf642d4e1b4f606d1ab06e43', commit_message='Upload folder using huggingface_hub', commit_description='', oid='6d3a1c9c577bd79abf642d4e1b4f606d1ab06e43', pr_url=None, pr_revision=None, pr_num=None)
